# %% [markdown]
# # BackTrader

# %%
from __future__ import (absolute_import, division, print_function,unicode_literals)
import datetime  # For datetime objects
import os.path  # To manage paths
import sys  # To find out the script name (in argv[0])
import numpy as np
import pandas as pd
# 画图
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec # Alignments
import seaborn as sns # theme & dataset
plt.rcParams['figure.dpi'] = 100
plt.rcParams['font.sans-serif']=['FangSong']
plt.rcParams['axes.unicode_minus']=False

import backtrader as bt

import tushare as ts
token = 'd9645bfd8516b93f1312d8ba696c83b606a78d966e71ec5c1e79bef4'
ts.set_token(token) 
pro = ts.pro_api(token)

# %%
# 使用Tushare获取数据，要严格保持OHLC的格式
df = ts.pro_bar(ts_code='600276.SH', adj='qfq',start_date='20160101', end_date='20210906')
df = df[['trade_date', 'open', 'high', 'low', 'close','vol']]
df.trade_date = pd.to_datetime(df.trade_date)
# 索引必须是日期
df.index = df.trade_date
# 日期必须要升序
df.sort_index(inplace=True)
df
# Out:
# HTTPConnectionPool(host='api.waditu.com', port=80): Read timed out. (read timeout=30)
#            trade_date     open     high      low    close        vol
# trade_date
# 2016-01-04 2016-01-04  14.9747  14.9747  14.3587  14.3953   86744.76
# 2016-01-05 2016-01-05  14.1818  14.6393  14.1665  14.5051   95328.66
# 2016-01-06 2016-01-06  14.5051  14.9076  14.4563  14.7979   86670.45
# 2016-01-07 2016-01-07  14.7155  14.7155  13.9225  14.0872   15488.00
# 2016-01-08 2016-01-08  14.4258  14.6362  14.0293  14.5325  112455.96
# ...               ...      ...      ...      ...      ...        ...
# 2021-08-31 2021-08-31  45.4500  46.1400  44.3300  45.2000  495741.85
# 2021-09-01 2021-09-01  45.4000  47.2000  44.9200  46.5900  731270.61
# 2021-09-02 2021-09-02  46.6000  46.6000  45.5000  45.8600  465752.10
# 2021-09-03 2021-09-03  45.3200  46.8400  45.0500  46.1000  462357.55
# 2021-09-06 2021-09-06  46.1900  48.8900  46.1900  48.1000  866635.69
#
# [1383 rows x 6 columns]

# %% [markdown]
# ## 策略：3天价格连续下跌买入，持股5天后卖出

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):
    # 设定参数，便于修改
    params = (
        ('exitbars', 5),
    )

    def log(self, txt, dt=None):
        ''' 
        日志函数：打印结果
        datas[0]：传入的数据，包含日期、OHLC等数据
        datas[0].datetime.date(0)：调用传入数据中的日期列
        '''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # dataclose变量：跟踪当前收盘价
        self.dataclose = self.datas[0].close

        # order变量：跟踪订单状态
        self.order = None
        # buyprice变量：买入价格
        self.buyprice = None
        # buycomm变量：买入时佣金费用
        self.buycomm = None

    def notify_order(self, order):
        '''订单状态通知(order.status)：提示成交状态'''
        if order.status in [order.Submitted, order.Accepted]:
            # 如果订单只是提交状态，那么啥也不提示
            return

        # 检查订单是否执行完毕
        # 注意：如果剩余现金不足，则会被拒绝！
        if order.status in [order.Completed]:
            if order.isbuy():
                # 买入信号记录：买入价、买入费用、买入佣金费用
                self.log(
                        'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                        (order.executed.price,
                         order.executed.value,
                         order.executed.comm))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            elif order.issell():
                # 卖出信号记录：卖出价、卖出费用、卖出佣金费用
                self.log(
                        'SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                        (order.executed.price,
                         order.executed.value,
                         order.executed.comm))
            
            # 记录订单执行的价格柱的编号（即长度）
            self.bar_executed = len(self)

        # 如果订单被取消/保证金不足/被拒绝
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # 如果没有查询到订单，则订单为None
        self.order = None

    def notify_trade(self, trade):
        '''交易状态通知：查看交易毛/净利润'''
        if not trade.isclosed:
            return
        # 交易毛利润：trade.pnl、交易净利润：trade.pnlcomm（扣除佣金）
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                    (trade.pnl, trade.pnlcomm))


    # 交易策略主函数
    def next(self):
        # 记录收盘价
        self.log('Close, %.2f' % self.dataclose[0])

        # 检查一下是否有订单被挂起，如果有的话就先不下单
        if self.order:
            return
        
        # 检查一下目前是否持有头寸，如果没有就建仓
        # 策略：价格连续跌3天就买
        if not self.position:

            # 如果现价<昨日价格
            if self.dataclose[0] < self.dataclose[-1]:
                # 如果昨日价格<前日价格
                if self.dataclose[-1] < self.dataclose[-2]:
                    # 买买买！先记录一下买入价格（收盘价）
                    self.log('BUY CREATE, %.2f' % self.dataclose[0])
                    # 更新订单状态：buy()：开仓买入，买入价是下一个数据，即【开盘价】
                    self.order = self.buy()
        else:
             # 如果已经建仓，并持有头寸，则执行卖出指令
             # 如果当前价格柱已经距离执行订单过去5个，则卖出
             # 这里的【self.params.exitbars：5】可以通过最开始的params中的参数进行修改
            if len(self) >= (self.bar_executed + self.params.exitbars):
                # 卖!卖!卖!
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                # 更新订单状态：sell()：平仓卖出，卖出价是下一个数据，即【开盘价】
                self.order = self.sell()

# 创建实例
cerebro = bt.Cerebro()

 # 添加策略
cerebro.addstrategy(TestStrategy)

# 添加数据源
data = bt.feeds.PandasData(dataname=df)

# 输入数据源
cerebro.adddata(data)

# 设置初始现金：10万
cerebro.broker.setcash(100000.0)

# 设定每次买入的股票数量：10股
cerebro.addsizer(bt.sizers.FixedSize, stake=1000)

# 设置佣金费率：双边0.1%
cerebro.broker.setcommission(commission=0.001)

# 显示：初始资产
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

# 运行策略
cerebro.run()

# 显示：最终资产
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 100000.00
# 2016-01-04, Close, 14.40
# 2016-01-05, Close, 14.51
# 2016-01-06, Close, 14.80
# 2016-01-07, Close, 14.09
# 2016-01-08, Close, 14.53
# 2016-01-11, Close, 13.89
# 2016-01-12, Close, 13.74
# 2016-01-12, BUY CREATE, 13.74
# 2016-01-13, BUY EXECUTED, Price: 13.75, Cost: 13754.80, Comm 13.75
# 2016-01-13, Close, 13.40
# 2016-01-14, Close, 13.52
# 2016-01-15, Close, 13.12
# 2016-01-18, Close, 13.23
# 2016-01-19, Close, 13.52
# 2016-01-20, Close, 13.52
# 2016-01-20, SELL CREATE, 13.52
# 2016-01-21, SELL EXECUTED, Price: 13.39, Cost: 13754.80, Comm 13.39
# 2016-01-21, OPERATION PROFIT, GROSS -366.00, NET -393.14
# 2016-01-21, Close, 13.08
# 2016-01-21, BUY CREATE, 13.08
# 2016-01-22, BUY EXECUTED, Price: 13.20, Cost: 13202.80, Comm 13.20
# 2016-01-22, Close, 13.21
# 2016-01-25, Close, 13.41
# 2016-01-26, Close, 13.09
# 2016-01-27, Close, 13.22
# 2016-01-28, Close, 12.98
# 2016-01-29, Close, 13.42
# 2016-01-29, SELL CREATE, 13.42
# 2016-02-01, SELL EXECUTED, Price: 13.41, Cost: 13202.80, Comm 13.41
# 2016-02-01, OPERATION PROFIT, GROSS 204.30, NET 177.69
# 2016-02-01, Close, 13.62
# 2016-02-02, Close, 13.71
# 2016-02-03, Close, 14.03
# 2016-02-04, Close, 13.96
# 2016-02-05, Close, 13.80
# 2016-02-05, BUY CREATE, 13.80
# 2016-02-15, BUY EXECUTED, Price: 13.66, Cost: 13663.30, Comm 13.66
# 2016-02-15, Close, 13.83
# 2016-02-16, Close, 14.05
# 2016-02-17, Close, 13.88
# 2016-02-18, Close, 13.70
# 2016-02-19, Close, 13.89
# 2016-02-22, Close, 14.11
# 2016-02-22, SELL CREATE, 14.11
# 2016-02-23, SELL EXECUTED, Price: 14.07, Cost: 13663.30, Comm 14.07
# 2016-02-23, OPERATION PROFIT, GROSS 402.60, NET 374.87
# 2016-02-23, Close, 14.24
# 2016-02-24, Close, 14.32
# 2016-02-25, Close, 13.93
# 2016-02-26, Close, 14.03
# 2016-02-29, Close, 13.72
# 2016-03-01, Close, 13.64
# 2016-03-01, BUY CREATE, 13.64
# 2016-03-02, BUY EXECUTED, Price: 13.60, Cost: 13602.30, Comm 13.60
# 2016-03-02, Close, 13.99
# 2016-03-03, Close, 14.24
# 2016-03-04, Close, 14.48
# 2016-03-07, Close, 14.55
# 2016-03-08, Close, 14.54
# 2016-03-09, Close, 14.69
# 2016-03-09, SELL CREATE, 14.69
# 2016-03-10, SELL EXECUTED, Price: 14.61, Cost: 13602.30, Comm 14.61
# 2016-03-10, OPERATION PROFIT, GROSS 1006.50, NET 978.29
# 2016-03-10, Close, 14.22
# 2016-03-11, Close, 14.20
# 2016-03-11, BUY CREATE, 14.20
# 2016-03-14, BUY EXECUTED, Price: 14.26, Cost: 14261.10, Comm 14.26
# 2016-03-14, Close, 14.27
# 2016-03-15, Close, 14.62
# 2016-03-16, Close, 14.67
# 2016-03-17, Close, 14.76
# 2016-03-18, Close, 14.53
# 2016-03-21, Close, 14.59
# 2016-03-21, SELL CREATE, 14.59
# 2016-03-22, SELL EXECUTED, Price: 14.58, Cost: 14261.10, Comm 14.58
# 2016-03-22, OPERATION PROFIT, GROSS 317.20, NET 288.36
# 2016-03-22, Close, 14.40
# 2016-03-23, Close, 14.40
# 2016-03-24, Close, 14.42
# 2016-03-25, Close, 14.45
# 2016-03-28, Close, 14.31
# 2016-03-29, Close, 14.23
# 2016-03-29, BUY CREATE, 14.23
# 2016-03-30, BUY EXECUTED, Price: 14.26, Cost: 14258.00, Comm 14.26
# 2016-03-30, Close, 14.43
# 2016-03-31, Close, 14.40
# 2016-04-01, Close, 14.50
# 2016-04-05, Close, 14.61
# 2016-04-06, Close, 14.51
# 2016-04-07, Close, 14.55
# 2016-04-07, SELL CREATE, 14.55
# 2016-04-08, SELL EXECUTED, Price: 14.44, Cost: 14258.00, Comm 14.44
# 2016-04-08, OPERATION PROFIT, GROSS 186.10, NET 157.40
# 2016-04-08, Close, 14.44
# 2016-04-11, Close, 14.34
# 2016-04-11, BUY CREATE, 14.34
# 2016-04-13, BUY EXECUTED, Price: 14.43, Cost: 14425.80, Comm 14.43
# 2016-04-13, Close, 14.37
# 2016-04-14, Close, 14.40
# 2016-04-15, Close, 14.53
# 2016-04-18, Close, 14.68
# 2016-04-19, Close, 14.57
# 2016-04-20, Close, 14.59
# 2016-04-20, SELL CREATE, 14.59
# 2016-04-21, SELL EXECUTED, Price: 14.38, Cost: 14425.80, Comm 14.38
# 2016-04-21, OPERATION PROFIT, GROSS -45.80, NET -74.61
# 2016-04-21, Close, 14.26
# 2016-04-22, Close, 14.29
# 2016-04-25, Close, 14.19
# 2016-04-26, Close, 14.44
# 2016-04-27, Close, 14.43
# 2016-04-28, Close, 14.26
# 2016-04-28, BUY CREATE, 14.26
# 2016-04-29, BUY EXECUTED, Price: 14.22, Cost: 14221.40, Comm 14.22
# 2016-04-29, Close, 14.24
# 2016-05-03, Close, 14.58
# 2016-05-04, Close, 14.58
# 2016-05-05, Close, 14.50
# 2016-05-06, Close, 14.31
# 2016-05-09, Close, 14.14
# 2016-05-09, SELL CREATE, 14.14
# 2016-05-10, SELL EXECUTED, Price: 14.09, Cost: 14221.40, Comm 14.09
# 2016-05-10, OPERATION PROFIT, GROSS -131.10, NET -159.41
# 2016-05-10, Close, 14.13
# 2016-05-10, BUY CREATE, 14.13
# 2016-05-11, BUY EXECUTED, Price: 14.13, Cost: 14129.90, Comm 14.13
# 2016-05-11, Close, 14.41
# 2016-05-12, Close, 14.31
# 2016-05-13, Close, 14.28
# 2016-05-16, Close, 14.34
# 2016-05-17, Close, 14.44
# 2016-05-18, Close, 14.38
# 2016-05-18, SELL CREATE, 14.38
# 2016-05-19, SELL EXECUTED, Price: 14.26, Cost: 14129.90, Comm 14.26
# 2016-05-19, OPERATION PROFIT, GROSS 128.10, NET 99.71
# 2016-05-19, Close, 14.22
# 2016-05-19, BUY CREATE, 14.22
# 2016-05-20, BUY EXECUTED, Price: 14.16, Cost: 14160.40, Comm 14.16
# 2016-05-20, Close, 14.18
# 2016-05-23, Close, 14.00
# 2016-05-24, Close, 14.00
# 2016-05-25, Close, 13.79
# 2016-05-26, Close, 13.77
# 2016-05-27, Close, 13.68
# 2016-05-27, SELL CREATE, 13.68
# 2016-05-30, SELL EXECUTED, Price: 13.63, Cost: 14160.40, Comm 13.63
# 2016-05-30, OPERATION PROFIT, GROSS -533.70, NET -561.49
# 2016-05-30, Close, 13.72
# 2016-05-31, Close, 14.01
# 2016-06-01, Close, 13.94
# 2016-06-02, Close, 13.89
# 2016-06-02, BUY CREATE, 13.89
# 2016-06-03, BUY EXECUTED, Price: 13.97, Cost: 13965.20, Comm 13.97
# 2016-06-03, Close, 14.25
# 2016-06-06, Close, 14.21
# 2016-06-07, Close, 14.19
# 2016-06-08, Close, 14.24
# 2016-06-13, Close, 14.06
# 2016-06-14, Close, 14.00
# 2016-06-14, SELL CREATE, 14.00
# 2016-06-15, SELL EXECUTED, Price: 13.97, Cost: 13965.20, Comm 13.97
# 2016-06-15, OPERATION PROFIT, GROSS 0.00, NET -27.93
# 2016-06-15, Close, 14.09
# 2016-06-16, Close, 14.27
# 2016-06-17, Close, 14.43
# 2016-06-20, Close, 14.37
# 2016-06-21, Close, 14.38
# 2016-06-22, Close, 14.59
# 2016-06-23, Close, 14.63
# 2016-06-24, Close, 14.44
# 2016-06-27, Close, 14.81
# 2016-06-28, Close, 14.87
# 2016-06-29, Close, 14.78
# 2016-06-30, Close, 14.71
# 2016-06-30, BUY CREATE, 14.71
# 2016-07-01, BUY EXECUTED, Price: 14.70, Cost: 14698.80, Comm 14.70
# 2016-07-01, Close, 14.78
# 2016-07-04, Close, 14.97
# 2016-07-05, Close, 14.87
# 2016-07-06, Close, 14.97
# 2016-07-07, Close, 15.03
# 2016-07-08, Close, 14.87
# 2016-07-08, SELL CREATE, 14.87
# 2016-07-11, SELL EXECUTED, Price: 14.90, Cost: 14698.80, Comm 14.90
# 2016-07-11, OPERATION PROFIT, GROSS 198.00, NET 168.40
# 2016-07-11, Close, 15.43
# 2016-07-12, Close, 15.86
# 2016-07-13, Close, 15.80
# 2016-07-14, Close, 15.73
# 2016-07-14, BUY CREATE, 15.73
# 2016-07-15, BUY EXECUTED, Price: 15.81, Cost: 15813.60, Comm 15.81
# 2016-07-15, Close, 15.84
# 2016-07-18, Close, 15.94
# 2016-07-19, Close, 15.65
# 2016-07-20, Close, 15.70
# 2016-07-21, Close, 15.64
# 2016-07-22, Close, 15.45
# 2016-07-22, SELL CREATE, 15.45
# 2016-07-25, SELL EXECUTED, Price: 15.40, Cost: 15813.60, Comm 15.40
# 2016-07-25, OPERATION PROFIT, GROSS -410.70, NET -441.92
# 2016-07-25, Close, 15.72
# 2016-07-26, Close, 15.74
# 2016-07-27, Close, 15.82
# 2016-07-28, Close, 16.06
# 2016-07-29, Close, 16.02
# 2016-08-01, Close, 15.83
# 2016-08-01, BUY CREATE, 15.83
# 2016-08-02, BUY EXECUTED, Price: 15.78, Cost: 15784.30, Comm 15.78
# 2016-08-02, Close, 16.06
# 2016-08-03, Close, 16.07
# 2016-08-04, Close, 15.96
# 2016-08-05, Close, 16.08
# 2016-08-08, Close, 16.02
# 2016-08-09, Close, 16.47
# 2016-08-09, SELL CREATE, 16.47
# 2016-08-10, SELL EXECUTED, Price: 16.47, Cost: 15784.30, Comm 16.47
# 2016-08-10, OPERATION PROFIT, GROSS 689.50, NET 657.24
# 2016-08-10, Close, 16.40
# 2016-08-11, Close, 16.35
# 2016-08-11, BUY CREATE, 16.35
# 2016-08-12, BUY EXECUTED, Price: 16.33, Cost: 16334.40, Comm 16.33
# 2016-08-12, Close, 16.42
# 2016-08-15, Close, 16.62
# 2016-08-16, Close, 16.61
# 2016-08-17, Close, 16.46
# 2016-08-18, Close, 16.32
# 2016-08-19, Close, 16.31
# 2016-08-19, SELL CREATE, 16.31
# 2016-08-22, SELL EXECUTED, Price: 16.35, Cost: 16334.40, Comm 16.35
# 2016-08-22, OPERATION PROFIT, GROSS 18.30, NET -14.39
# 2016-08-22, Close, 16.36
# 2016-08-23, Close, 16.20
# 2016-08-24, Close, 16.17
# 2016-08-24, BUY CREATE, 16.17
# 2016-08-25, BUY EXECUTED, Price: 16.12, Cost: 16118.00, Comm 16.12
# 2016-08-25, Close, 16.18
# 2016-08-26, Close, 16.19
# 2016-08-29, Close, 16.28
# 2016-08-30, Close, 15.86
# 2016-08-31, Close, 15.89
# 2016-09-01, Close, 15.97
# 2016-09-01, SELL CREATE, 15.97
# 2016-09-02, SELL EXECUTED, Price: 15.90, Cost: 16118.00, Comm 15.90
# 2016-09-02, OPERATION PROFIT, GROSS -220.00, NET -252.02
# 2016-09-02, Close, 16.33
# 2016-09-05, Close, 16.18
# 2016-09-06, Close, 16.19
# 2016-09-07, Close, 16.02
# 2016-09-08, Close, 15.95
# 2016-09-08, BUY CREATE, 15.95
# 2016-09-09, BUY EXECUTED, Price: 15.99, Cost: 15986.00, Comm 15.99
# 2016-09-09, Close, 15.84
# 2016-09-12, Close, 16.09
# 2016-09-13, Close, 15.98
# 2016-09-14, Close, 15.65
# 2016-09-19, Close, 15.84
# 2016-09-20, Close, 15.95
# 2016-09-20, SELL CREATE, 15.95
# 2016-09-21, SELL EXECUTED, Price: 15.97, Cost: 15986.00, Comm 15.97
# 2016-09-21, OPERATION PROFIT, GROSS -11.00, NET -42.96
# 2016-09-21, Close, 15.97
# 2016-09-22, Close, 16.03
# 2016-09-23, Close, 16.31
# 2016-09-26, Close, 16.08
# 2016-09-27, Close, 16.02
# 2016-09-27, BUY CREATE, 16.02
# 2016-09-28, BUY EXECUTED, Price: 16.05, Cost: 16048.40, Comm 16.05
# 2016-09-28, Close, 16.05
# 2016-09-29, Close, 16.10
# 2016-09-30, Close, 16.15
# 2016-10-10, Close, 16.58
# 2016-10-11, Close, 16.81
# 2016-10-12, Close, 16.74
# 2016-10-12, SELL CREATE, 16.74
# 2016-10-13, SELL EXECUTED, Price: 16.69, Cost: 16048.40, Comm 16.69
# 2016-10-13, OPERATION PROFIT, GROSS 638.10, NET 605.37
# 2016-10-13, Close, 16.92
# 2016-10-14, Close, 16.84
# 2016-10-17, Close, 17.18
# 2016-10-18, Close, 17.16
# 2016-10-19, Close, 17.27
# 2016-10-20, Close, 17.07
# 2016-10-21, Close, 17.09
# 2016-10-24, Close, 16.98
# 2016-10-25, Close, 16.87
# 2016-10-25, BUY CREATE, 16.87
# 2016-10-26, BUY EXECUTED, Price: 16.90, Cost: 16902.90, Comm 16.90
# 2016-10-26, Close, 17.06
# 2016-10-27, Close, 17.09
# 2016-10-28, Close, 16.95
# 2016-10-31, Close, 16.92
# 2016-11-01, Close, 17.20
# 2016-11-02, Close, 17.15
# 2016-11-02, SELL CREATE, 17.15
# 2016-11-03, SELL EXECUTED, Price: 17.13, Cost: 16902.90, Comm 17.13
# 2016-11-03, OPERATION PROFIT, GROSS 223.70, NET 189.67
# 2016-11-03, Close, 17.08
# 2016-11-03, BUY CREATE, 17.08
# 2016-11-04, BUY EXECUTED, Price: 16.94, Cost: 16943.20, Comm 16.94
# 2016-11-04, Close, 16.78
# 2016-11-07, Close, 16.65
# 2016-11-08, Close, 16.97
# 2016-11-09, Close, 16.95
# 2016-11-10, Close, 16.83
# 2016-11-11, Close, 16.74
# 2016-11-11, SELL CREATE, 16.74
# 2016-11-14, SELL EXECUTED, Price: 16.76, Cost: 16943.20, Comm 16.76
# 2016-11-14, OPERATION PROFIT, GROSS -183.40, NET -217.10
# 2016-11-14, Close, 16.55
# 2016-11-14, BUY CREATE, 16.55
# 2016-11-15, BUY EXECUTED, Price: 16.55, Cost: 16547.10, Comm 16.55
# 2016-11-15, Close, 16.61
# 2016-11-16, Close, 16.81
# 2016-11-17, Close, 16.82
# 2016-11-18, Close, 16.70
# 2016-11-21, Close, 16.82
# 2016-11-22, Close, 16.98
# 2016-11-22, SELL CREATE, 16.98
# 2016-11-23, SELL EXECUTED, Price: 16.96, Cost: 16547.10, Comm 16.96
# 2016-11-23, OPERATION PROFIT, GROSS 414.40, NET 380.89
# 2016-11-23, Close, 16.91
# 2016-11-24, Close, 17.10
# 2016-11-25, Close, 17.09
# 2016-11-28, Close, 17.00
# 2016-11-28, BUY CREATE, 17.00
# 2016-11-29, BUY EXECUTED, Price: 17.00, Cost: 16998.20, Comm 17.00
# 2016-11-29, Close, 17.00
# 2016-11-30, Close, 17.19
# 2016-12-01, Close, 17.19
# 2016-12-02, Close, 17.25
# 2016-12-05, Close, 17.27
# 2016-12-06, Close, 17.55
# 2016-12-06, SELL CREATE, 17.55
# 2016-12-07, SELL EXECUTED, Price: 17.60, Cost: 16998.20, Comm 17.60
# 2016-12-07, OPERATION PROFIT, GROSS 605.10, NET 570.50
# 2016-12-07, Close, 17.54
# 2016-12-08, Close, 17.34
# 2016-12-08, BUY CREATE, 17.34
# 2016-12-09, BUY EXECUTED, Price: 17.34, Cost: 17339.30, Comm 17.34
# 2016-12-09, Close, 17.20
# 2016-12-12, Close, 17.36
# 2016-12-13, Close, 17.16
# 2016-12-14, Close, 17.14
# 2016-12-15, Close, 17.05
# 2016-12-16, Close, 17.09
# 2016-12-16, SELL CREATE, 17.09
# 2016-12-19, SELL EXECUTED, Price: 17.13, Cost: 17339.30, Comm 17.13
# 2016-12-19, OPERATION PROFIT, GROSS -212.70, NET -247.17
# 2016-12-19, Close, 17.15
# 2016-12-20, Close, 16.83
# 2016-12-21, Close, 16.90
# 2016-12-22, Close, 16.62
# 2016-12-23, Close, 16.62
# 2016-12-26, Close, 16.77
# 2016-12-27, Close, 16.84
# 2016-12-28, Close, 16.68
# 2016-12-29, Close, 16.69
# 2016-12-30, Close, 16.69
# 2017-01-03, Close, 16.87
# 2017-01-04, Close, 17.08
# 2017-01-05, Close, 17.09
# 2017-01-06, Close, 16.87
# 2017-01-09, Close, 16.71
# 2017-01-09, BUY CREATE, 16.71
# 2017-01-10, BUY EXECUTED, Price: 16.70, Cost: 16704.80, Comm 16.70
# 2017-01-10, Close, 16.88
# 2017-01-11, Close, 16.60
# 2017-01-12, Close, 16.60
# 2017-01-13, Close, 16.75
# 2017-01-16, Close, 17.05
# 2017-01-17, Close, 16.98
# 2017-01-17, SELL CREATE, 16.98
# 2017-01-18, SELL EXECUTED, Price: 17.01, Cost: 16704.80, Comm 17.01
# 2017-01-18, OPERATION PROFIT, GROSS 304.40, NET 270.69
# 2017-01-18, Close, 17.06
# 2017-01-19, Close, 17.22
# 2017-01-20, Close, 17.24
# 2017-01-23, Close, 17.46
# 2017-01-24, Close, 17.18
# 2017-01-25, Close, 17.52
# 2017-01-26, Close, 17.54
# 2017-02-03, Close, 17.93
# 2017-02-06, Close, 17.71
# 2017-02-07, Close, 17.59
# 2017-02-07, BUY CREATE, 17.59
# 2017-02-08, BUY EXECUTED, Price: 17.65, Cost: 17647.30, Comm 17.65
# 2017-02-08, Close, 17.70
# 2017-02-09, Close, 17.66
# 2017-02-10, Close, 17.53
# 2017-02-13, Close, 17.56
# 2017-02-14, Close, 17.72
# 2017-02-15, Close, 17.56
# 2017-02-15, SELL CREATE, 17.56
# 2017-02-16, SELL EXECUTED, Price: 17.57, Cost: 17647.30, Comm 17.57
# 2017-02-16, OPERATION PROFIT, GROSS -80.70, NET -115.91
# 2017-02-16, Close, 18.12
# 2017-02-17, Close, 18.00
# 2017-02-20, Close, 18.24
# 2017-02-21, Close, 18.28
# 2017-02-22, Close, 18.32
# 2017-02-23, Close, 18.46
# 2017-02-24, Close, 18.84
# 2017-02-27, Close, 18.63
# 2017-02-28, Close, 18.48
# 2017-02-28, BUY CREATE, 18.48
# 2017-03-01, BUY EXECUTED, Price: 18.46, Cost: 18461.50, Comm 18.46
# 2017-03-01, Close, 18.28
# 2017-03-02, Close, 18.19
# 2017-03-03, Close, 18.26
# 2017-03-06, Close, 18.41
# 2017-03-07, Close, 18.76
# 2017-03-08, Close, 18.84
# 2017-03-08, SELL CREATE, 18.84
# 2017-03-09, SELL EXECUTED, Price: 18.95, Cost: 18461.50, Comm 18.95
# 2017-03-09, OPERATION PROFIT, GROSS 491.40, NET 453.99
# 2017-03-09, Close, 18.76
# 2017-03-10, Close, 18.81
# 2017-03-13, Close, 18.62
# 2017-03-14, Close, 18.66
# 2017-03-15, Close, 19.16
# 2017-03-16, Close, 19.00
# 2017-03-17, Close, 19.06
# 2017-03-20, Close, 19.22
# 2017-03-21, Close, 19.61
# 2017-03-22, Close, 19.68
# 2017-03-23, Close, 19.67
# 2017-03-24, Close, 19.61
# 2017-03-24, BUY CREATE, 19.61
# 2017-03-27, BUY EXECUTED, Price: 19.58, Cost: 19576.40, Comm 19.58
# 2017-03-27, Close, 19.73
# 2017-03-28, Close, 19.75
# 2017-03-29, Close, 19.57
# 2017-03-30, Close, 19.52
# 2017-03-31, Close, 19.92
# 2017-04-05, Close, 19.98
# 2017-04-05, SELL CREATE, 19.98
# 2017-04-06, SELL EXECUTED, Price: 20.10, Cost: 19576.40, Comm 20.10
# 2017-04-06, OPERATION PROFIT, GROSS 520.70, NET 481.03
# 2017-04-06, Close, 20.07
# 2017-04-07, Close, 20.11
# 2017-04-10, Close, 19.77
# 2017-04-11, Close, 19.40
# 2017-04-11, BUY CREATE, 19.40
# 2017-04-12, BUY EXECUTED, Price: 19.36, Cost: 19363.60, Comm 19.36
# 2017-04-12, Close, 19.57
# 2017-04-13, Close, 19.86
# 2017-04-14, Close, 19.80
# 2017-04-17, Close, 19.87
# 2017-04-18, Close, 20.16
# 2017-04-19, Close, 20.16
# 2017-04-19, SELL CREATE, 20.16
# 2017-04-20, SELL EXECUTED, Price: 20.16, Cost: 19363.60, Comm 20.16
# 2017-04-20, OPERATION PROFIT, GROSS 799.50, NET 759.97
# 2017-04-20, Close, 20.46
# 2017-04-21, Close, 20.64
# 2017-04-24, Close, 20.75
# 2017-04-25, Close, 20.68
# 2017-04-26, Close, 20.38
# 2017-04-26, BUY CREATE, 20.38
# 2017-04-27, BUY EXECUTED, Price: 20.36, Cost: 20357.50, Comm 20.36
# 2017-04-27, Close, 20.06
# 2017-04-28, Close, 19.67
# 2017-05-02, Close, 19.49
# 2017-05-03, Close, 19.70
# 2017-05-04, Close, 19.95
# 2017-05-05, Close, 20.04
# 2017-05-05, SELL CREATE, 20.04
# 2017-05-08, SELL EXECUTED, Price: 20.03, Cost: 20357.50, Comm 20.03
# 2017-05-08, OPERATION PROFIT, GROSS -330.10, NET -370.48
# 2017-05-08, Close, 20.07
# 2017-05-09, Close, 19.94
# 2017-05-10, Close, 20.30
# 2017-05-11, Close, 20.51
# 2017-05-12, Close, 20.52
# 2017-05-15, Close, 20.72
# 2017-05-16, Close, 21.20
# 2017-05-17, Close, 21.07
# 2017-05-18, Close, 21.58
# 2017-05-19, Close, 21.54
# 2017-05-22, Close, 21.75
# 2017-05-23, Close, 22.08
# 2017-05-24, Close, 22.04
# 2017-05-25, Close, 21.49
# 2017-05-25, BUY CREATE, 21.49
# 2017-05-26, BUY EXECUTED, Price: 21.49, Cost: 21490.70, Comm 21.49
# 2017-05-26, Close, 21.60
# 2017-05-31, Close, 21.96
# 2017-06-01, Close, 22.39
# 2017-06-02, Close, 22.09
# 2017-06-05, Close, 21.51
# 2017-06-06, Close, 21.83
# 2017-06-06, SELL CREATE, 21.83
# 2017-06-07, SELL EXECUTED, Price: 21.82, Cost: 21490.70, Comm 21.82
# 2017-06-07, OPERATION PROFIT, GROSS 327.30, NET 283.99
# 2017-06-07, Close, 22.21
# 2017-06-08, Close, 22.61
# 2017-06-09, Close, 22.56
# 2017-06-12, Close, 22.60
# 2017-06-13, Close, 22.41
# 2017-06-14, Close, 22.42
# 2017-06-15, Close, 22.29
# 2017-06-16, Close, 22.66
# 2017-06-19, Close, 22.18
# 2017-06-20, Close, 21.75
# 2017-06-20, BUY CREATE, 21.75
# 2017-06-21, BUY EXECUTED, Price: 21.84, Cost: 21835.60, Comm 21.84
# 2017-06-21, Close, 22.05
# 2017-06-22, Close, 21.84
# 2017-06-23, Close, 22.11
# 2017-06-26, Close, 22.54
# 2017-06-27, Close, 22.54
# 2017-06-28, Close, 22.10
# 2017-06-28, SELL CREATE, 22.10
# 2017-06-29, SELL EXECUTED, Price: 22.06, Cost: 21835.60, Comm 22.06
# 2017-06-29, OPERATION PROFIT, GROSS 225.00, NET 181.10
# 2017-06-29, Close, 22.33
# 2017-06-30, Close, 22.32
# 2017-07-03, Close, 22.09
# 2017-07-03, BUY CREATE, 22.09
# 2017-07-04, BUY EXECUTED, Price: 22.01, Cost: 22012.10, Comm 22.01
# 2017-07-04, Close, 21.69
# 2017-07-05, Close, 21.95
# 2017-07-06, Close, 21.73
# 2017-07-07, Close, 21.54
# 2017-07-10, Close, 21.76
# 2017-07-11, Close, 21.84
# 2017-07-11, SELL CREATE, 21.84
# 2017-07-12, SELL EXECUTED, Price: 21.95, Cost: 22012.10, Comm 21.95
# 2017-07-12, OPERATION PROFIT, GROSS -66.20, NET -110.16
# 2017-07-12, Close, 21.65
# 2017-07-13, Close, 21.66
# 2017-07-14, Close, 21.49
# 2017-07-17, Close, 21.63
# 2017-07-18, Close, 22.11
# 2017-07-19, Close, 22.28
# 2017-07-20, Close, 22.22
# 2017-07-21, Close, 22.02
# 2017-07-21, BUY CREATE, 22.02
# 2017-07-24, BUY EXECUTED, Price: 22.02, Cost: 22020.90, Comm 22.02
# 2017-07-24, Close, 22.08
# 2017-07-25, Close, 22.11
# 2017-07-26, Close, 22.16
# 2017-07-27, Close, 22.26
# 2017-07-28, Close, 22.45
# 2017-07-31, Close, 22.59
# 2017-07-31, SELL CREATE, 22.59
# 2017-08-01, SELL EXECUTED, Price: 22.58, Cost: 22020.90, Comm 22.58
# 2017-08-01, OPERATION PROFIT, GROSS 555.80, NET 511.20
# 2017-08-01, Close, 22.63
# 2017-08-02, Close, 22.16
# 2017-08-03, Close, 22.10
# 2017-08-03, BUY CREATE, 22.10
# 2017-08-04, BUY EXECUTED, Price: 22.09, Cost: 22087.10, Comm 22.09
# 2017-08-04, Close, 22.11
# 2017-08-07, Close, 22.37
# 2017-08-08, Close, 22.38
# 2017-08-09, Close, 23.35
# 2017-08-10, Close, 23.20
# 2017-08-11, Close, 23.44
# 2017-08-11, SELL CREATE, 23.44
# 2017-08-14, SELL EXECUTED, Price: 23.45, Cost: 22087.10, Comm 23.45
# 2017-08-14, OPERATION PROFIT, GROSS 1358.60, NET 1313.07
# 2017-08-14, Close, 24.24
# 2017-08-15, Close, 24.06
# 2017-08-16, Close, 23.85
# 2017-08-16, BUY CREATE, 23.85
# 2017-08-17, BUY EXECUTED, Price: 23.82, Cost: 23820.70, Comm 23.82
# 2017-08-17, Close, 23.64
# 2017-08-18, Close, 23.69
# 2017-08-21, Close, 24.17
# 2017-08-22, Close, 23.92
# 2017-08-23, Close, 24.09
# 2017-08-24, Close, 24.17
# 2017-08-24, SELL CREATE, 24.17
# 2017-08-25, SELL EXECUTED, Price: 24.22, Cost: 23820.70, Comm 24.22
# 2017-08-25, OPERATION PROFIT, GROSS 401.40, NET 353.36
# 2017-08-25, Close, 24.13
# 2017-08-28, Close, 23.83
# 2017-08-28, BUY CREATE, 23.83
# 2017-08-29, BUY EXECUTED, Price: 23.91, Cost: 23908.90, Comm 23.91
# 2017-08-29, Close, 23.82
# 2017-08-30, Close, 23.85
# 2017-08-31, Close, 23.88
# 2017-09-01, Close, 24.56
# 2017-09-04, Close, 25.77
# 2017-09-05, Close, 25.68
# 2017-09-05, SELL CREATE, 25.68
# 2017-09-06, SELL EXECUTED, Price: 25.59, Cost: 23908.90, Comm 25.59
# 2017-09-06, OPERATION PROFIT, GROSS 1680.70, NET 1631.20
# 2017-09-06, Close, 25.39
# 2017-09-06, BUY CREATE, 25.39
# 2017-09-07, BUY EXECUTED, Price: 25.36, Cost: 25364.60, Comm 25.36
# 2017-09-07, Close, 25.75
# 2017-09-08, Close, 26.22
# 2017-09-11, Close, 25.77
# 2017-09-12, Close, 25.71
# 2017-09-13, Close, 25.77
# 2017-09-14, Close, 25.47
# 2017-09-14, SELL CREATE, 25.47
# 2017-09-15, SELL EXECUTED, Price: 25.40, Cost: 25364.60, Comm 25.40
# 2017-09-15, OPERATION PROFIT, GROSS 35.30, NET -15.46
# 2017-09-15, Close, 25.69
# 2017-09-18, Close, 25.85
# 2017-09-19, Close, 25.92
# 2017-09-20, Close, 25.97
# 2017-09-21, Close, 25.69
# 2017-09-22, Close, 25.65
# 2017-09-22, BUY CREATE, 25.65
# 2017-09-25, BUY EXECUTED, Price: 25.70, Cost: 25695.50, Comm 25.70
# 2017-09-25, Close, 25.64
# 2017-09-26, Close, 25.62
# 2017-09-27, Close, 25.78
# 2017-09-28, Close, 26.50
# 2017-09-29, Close, 26.44
# 2017-10-09, Close, 27.33
# 2017-10-09, SELL CREATE, 27.33
# 2017-10-10, SELL EXECUTED, Price: 27.31, Cost: 25695.50, Comm 27.31
# 2017-10-10, OPERATION PROFIT, GROSS 1610.10, NET 1557.10
# 2017-10-10, Close, 26.87
# 2017-10-11, Close, 27.52
# 2017-10-12, Close, 27.76
# 2017-10-13, Close, 27.75
# 2017-10-16, Close, 27.79
# 2017-10-17, Close, 28.15
# 2017-10-18, Close, 28.07
# 2017-10-19, Close, 28.86
# 2017-10-20, Close, 28.66
# 2017-10-23, Close, 28.72
# 2017-10-24, Close, 28.61
# 2017-10-25, Close, 29.47
# 2017-10-26, Close, 29.23
# 2017-10-27, Close, 29.06
# 2017-10-27, BUY CREATE, 29.06
# 2017-10-30, BUY EXECUTED, Price: 29.06, Cost: 29061.20, Comm 29.06
# 2017-10-30, Close, 28.68
# 2017-10-31, Close, 29.66
# 2017-11-01, Close, 30.22
# 2017-11-02, Close, 30.47
# 2017-11-03, Close, 31.74
# 2017-11-06, Close, 33.39
# 2017-11-06, SELL CREATE, 33.39
# 2017-11-07, SELL EXECUTED, Price: 33.34, Cost: 29061.20, Comm 33.34
# 2017-11-07, OPERATION PROFIT, GROSS 4283.30, NET 4220.89
# 2017-11-07, Close, 31.89
# 2017-11-08, Close, 31.09
# 2017-11-08, BUY CREATE, 31.09
# 2017-11-09, BUY EXECUTED, Price: 30.88, Cost: 30878.70, Comm 30.88
# 2017-11-09, Close, 31.31
# 2017-11-10, Close, 31.55
# 2017-11-13, Close, 30.63
# 2017-11-14, Close, 29.59
# 2017-11-15, Close, 30.04
# 2017-11-16, Close, 30.82
# 2017-11-16, SELL CREATE, 30.82
# 2017-11-17, SELL EXECUTED, Price: 30.71, Cost: 30878.70, Comm 30.71
# 2017-11-17, OPERATION PROFIT, GROSS -172.10, NET -233.69
# 2017-11-17, Close, 29.87
# 2017-11-20, Close, 30.40
# 2017-11-21, Close, 30.53
# 2017-11-22, Close, 30.34
# 2017-11-23, Close, 28.63
# 2017-11-23, BUY CREATE, 28.63
# 2017-11-24, BUY EXECUTED, Price: 28.15, Cost: 28148.10, Comm 28.15
# 2017-11-24, Close, 28.78
# 2017-11-27, Close, 28.33
# 2017-11-28, Close, 29.22
# 2017-11-29, Close, 28.81
# 2017-11-30, Close, 28.76
# 2017-12-01, Close, 29.15
# 2017-12-01, SELL CREATE, 29.15
# 2017-12-04, SELL EXECUTED, Price: 28.90, Cost: 28148.10, Comm 28.90
# 2017-12-04, OPERATION PROFIT, GROSS 754.30, NET 697.25
# 2017-12-04, Close, 29.74
# 2017-12-05, Close, 29.29
# 2017-12-06, Close, 28.84
# 2017-12-06, BUY CREATE, 28.84
# 2017-12-07, BUY EXECUTED, Price: 28.81, Cost: 28805.40, Comm 28.81
# 2017-12-07, Close, 28.43
# 2017-12-08, Close, 28.86
# 2017-12-11, Close, 30.62
# 2017-12-12, Close, 30.34
# 2017-12-13, Close, 30.64
# 2017-12-14, Close, 30.72
# 2017-12-14, SELL CREATE, 30.72
# 2017-12-15, SELL EXECUTED, Price: 30.70, Cost: 28805.40, Comm 30.70
# 2017-12-15, OPERATION PROFIT, GROSS 1896.80, NET 1837.29
# 2017-12-15, Close, 29.80
# 2017-12-18, Close, 30.06
# 2017-12-19, Close, 30.28
# 2017-12-20, Close, 30.61
# 2017-12-21, Close, 31.23
# 2017-12-22, Close, 31.42
# 2017-12-25, Close, 31.32
# 2017-12-26, Close, 31.19
# 2017-12-26, BUY CREATE, 31.19
# 2017-12-27, BUY EXECUTED, Price: 31.27, Cost: 31266.90, Comm 31.27
# 2017-12-27, Close, 30.06
# 2017-12-28, Close, 30.62
# 2017-12-29, Close, 30.43
# 2018-01-02, Close, 30.29
# 2018-01-03, Close, 30.36
# 2018-01-04, Close, 31.13
# 2018-01-04, SELL CREATE, 31.13
# 2018-01-05, SELL EXECUTED, Price: 31.56, Cost: 31266.90, Comm 31.56
# 2018-01-05, OPERATION PROFIT, GROSS 295.50, NET 232.67
# 2018-01-05, Close, 31.02
# 2018-01-08, Close, 31.43
# 2018-01-09, Close, 32.95
# 2018-01-10, Close, 33.04
# 2018-01-11, Close, 32.76
# 2018-01-12, Close, 32.91
# 2018-01-15, Close, 32.86
# 2018-01-16, Close, 33.13
# 2018-01-17, Close, 32.44
# 2018-01-18, Close, 32.11
# 2018-01-18, BUY CREATE, 32.11
# 2018-01-19, BUY EXECUTED, Price: 32.15, Cost: 32149.10, Comm 32.15
# 2018-01-19, Close, 32.80
# 2018-01-22, Close, 33.70
# 2018-01-23, Close, 33.83
# 2018-01-24, Close, 34.44
# 2018-01-25, Close, 33.55
# 2018-01-26, Close, 34.03
# 2018-01-26, SELL CREATE, 34.03
# 2018-01-29, SELL EXECUTED, Price: 34.19, Cost: 32149.10, Comm 34.19
# 2018-01-29, OPERATION PROFIT, GROSS 2042.40, NET 1976.06
# 2018-01-29, Close, 32.31
# 2018-01-30, Close, 32.69
# 2018-01-31, Close, 33.39
# 2018-02-01, Close, 32.74
# 2018-02-02, Close, 32.77
# 2018-02-05, Close, 32.37
# 2018-02-06, Close, 30.44
# 2018-02-06, BUY CREATE, 30.44
# 2018-02-07, BUY EXECUTED, Price: 31.36, Cost: 31355.10, Comm 31.36
# 2018-02-07, Close, 29.86
# 2018-02-08, Close, 30.49
# 2018-02-09, Close, 29.80
# 2018-02-12, Close, 31.31
# 2018-02-13, Close, 31.42
# 2018-02-14, Close, 31.73
# 2018-02-14, SELL CREATE, 31.73
# 2018-02-22, SELL EXECUTED, Price: 31.76, Cost: 31355.10, Comm 31.76
# 2018-02-22, OPERATION PROFIT, GROSS 405.80, NET 342.68
# 2018-02-22, Close, 31.97
# 2018-02-23, Close, 32.33
# 2018-02-26, Close, 32.98
# 2018-02-27, Close, 32.50
# 2018-02-28, Close, 31.97
# 2018-02-28, BUY CREATE, 31.97
# 2018-03-01, BUY EXECUTED, Price: 31.89, Cost: 31893.20, Comm 31.89
# 2018-03-01, Close, 32.73
# 2018-03-02, Close, 32.54
# 2018-03-05, Close, 32.85
# 2018-03-06, Close, 33.61
# 2018-03-07, Close, 33.26
# 2018-03-08, Close, 34.52
# 2018-03-08, SELL CREATE, 34.52
# 2018-03-09, SELL EXECUTED, Price: 34.52, Cost: 31893.20, Comm 34.52
# 2018-03-09, OPERATION PROFIT, GROSS 2629.10, NET 2562.68
# 2018-03-09, Close, 35.02
# 2018-03-12, Close, 35.28
# 2018-03-13, Close, 34.77
# 2018-03-14, Close, 35.25
# 2018-03-15, Close, 36.48
# 2018-03-16, Close, 36.15
# 2018-03-19, Close, 38.09
# 2018-03-20, Close, 38.59
# 2018-03-21, Close, 38.16
# 2018-03-22, Close, 37.89
# 2018-03-22, BUY CREATE, 37.89
# 2018-03-23, BUY EXECUTED, Price: 36.76, Cost: 36758.80, Comm 36.76
# 2018-03-23, Close, 37.33
# 2018-03-26, Close, 38.53
# 2018-03-27, Close, 38.25
# 2018-03-28, Close, 36.72
# 2018-03-29, Close, 36.52
# 2018-03-30, Close, 38.38
# 2018-03-30, SELL CREATE, 38.38
# 2018-04-02, SELL EXECUTED, Price: 38.38, Cost: 36758.80, Comm 38.38
# 2018-04-02, OPERATION PROFIT, GROSS 1623.40, NET 1548.26
# 2018-04-02, Close, 37.44
# 2018-04-03, Close, 37.43
# 2018-04-03, BUY CREATE, 37.43
# 2018-04-04, BUY EXECUTED, Price: 38.11, Cost: 38113.10, Comm 38.11
# 2018-04-04, Close, 37.10
# 2018-04-09, Close, 36.44
# 2018-04-10, Close, 37.21
# 2018-04-11, Close, 37.52
# 2018-04-12, Close, 37.82
# 2018-04-13, Close, 35.77
# 2018-04-13, SELL CREATE, 35.77
# 2018-04-16, SELL EXECUTED, Price: 36.02, Cost: 38113.10, Comm 36.02
# 2018-04-16, OPERATION PROFIT, GROSS -2095.30, NET -2169.43
# 2018-04-16, Close, 36.74
# 2018-04-17, Close, 35.67
# 2018-04-18, Close, 36.19
# 2018-04-19, Close, 36.63
# 2018-04-20, Close, 37.07
# 2018-04-23, Close, 37.18
# 2018-04-24, Close, 37.39
# 2018-04-25, Close, 38.58
# 2018-04-26, Close, 36.95
# 2018-04-27, Close, 36.83
# 2018-04-27, BUY CREATE, 36.83
# 2018-05-02, BUY EXECUTED, Price: 37.05, Cost: 37050.00, Comm 37.05
# 2018-05-02, Close, 36.14
# 2018-05-03, Close, 36.56
# 2018-05-04, Close, 36.37
# 2018-05-07, Close, 37.28
# 2018-05-08, Close, 37.74
# 2018-05-09, Close, 37.87
# 2018-05-09, SELL CREATE, 37.87
# 2018-05-10, SELL EXECUTED, Price: 38.30, Cost: 37050.00, Comm 38.30
# 2018-05-10, OPERATION PROFIT, GROSS 1248.40, NET 1173.05
# 2018-05-10, Close, 40.40
# 2018-05-11, Close, 39.47
# 2018-05-14, Close, 40.20
# 2018-05-15, Close, 40.77
# 2018-05-16, Close, 40.42
# 2018-05-17, Close, 39.67
# 2018-05-17, BUY CREATE, 39.67
# 2018-05-18, BUY EXECUTED, Price: 39.69, Cost: 39692.30, Comm 39.69
# 2018-05-18, Close, 40.70
# 2018-05-21, Close, 40.49
# 2018-05-22, Close, 41.97
# 2018-05-23, Close, 41.76
# 2018-05-24, Close, 41.51
# 2018-05-25, Close, 42.95
# 2018-05-25, SELL CREATE, 42.95
# 2018-05-28, SELL EXECUTED, Price: 43.34, Cost: 39692.30, Comm 43.34
# 2018-05-28, OPERATION PROFIT, GROSS 3648.10, NET 3565.07
# 2018-05-28, Close, 44.67
# 2018-05-29, Close, 42.09
# 2018-05-30, Close, 42.79
# 2018-05-31, Close, 43.72
# 2018-06-01, Close, 42.50
# 2018-06-04, Close, 43.49
# 2018-06-05, Close, 46.03
# 2018-06-06, Close, 47.32
# 2018-06-07, Close, 47.09
# 2018-06-08, Close, 46.60
# 2018-06-08, BUY CREATE, 46.60
# 2018-06-11, BUY EXECUTED, Price: 46.57, Cost: 46565.10, Comm 46.57
# 2018-06-11, Close, 44.80
# 2018-06-12, Close, 45.17
# 2018-06-13, Close, 44.23
# 2018-06-14, Close, 43.81
# 2018-06-15, Close, 43.61
# 2018-06-19, Close, 43.06
# 2018-06-19, SELL CREATE, 43.06
# 2018-06-20, SELL EXECUTED, Price: 43.07, Cost: 46565.10, Comm 43.07
# 2018-06-20, OPERATION PROFIT, GROSS -3497.10, NET -3586.73
# 2018-06-20, Close, 45.33
# 2018-06-21, Close, 44.90
# 2018-06-22, Close, 45.35
# 2018-06-25, Close, 45.72
# 2018-06-26, Close, 45.80
# 2018-06-27, Close, 43.90
# 2018-06-28, Close, 41.83
# 2018-06-28, BUY CREATE, 41.83
# 2018-06-29, BUY EXECUTED, Price: 42.02, Cost: 42022.90, Comm 42.02
# 2018-06-29, Close, 43.50
# 2018-07-02, Close, 43.30
# 2018-07-03, Close, 41.64
# 2018-07-04, Close, 40.24
# 2018-07-05, Close, 39.04
# 2018-07-06, Close, 40.19
# 2018-07-06, SELL CREATE, 40.19
# 2018-07-09, SELL EXECUTED, Price: 39.78, Cost: 42022.90, Comm 39.78
# 2018-07-09, OPERATION PROFIT, GROSS -2239.60, NET -2321.41
# 2018-07-09, Close, 41.51
# 2018-07-10, Close, 41.83
# 2018-07-11, Close, 41.56
# 2018-07-12, Close, 42.32
# 2018-07-13, Close, 43.06
# 2018-07-16, Close, 42.90
# 2018-07-17, Close, 41.78
# 2018-07-17, BUY CREATE, 41.78
# 2018-07-18, BUY EXECUTED, Price: 41.95, Cost: 41948.20, Comm 41.95
# 2018-07-18, Close, 42.55
# 2018-07-19, Close, 42.05
# 2018-07-20, Close, 42.36
# 2018-07-23, Close, 40.31
# 2018-07-24, Close, 40.78
# 2018-07-25, Close, 41.28
# 2018-07-25, SELL CREATE, 41.28
# 2018-07-26, SELL EXECUTED, Price: 41.45, Cost: 41948.20, Comm 41.45
# 2018-07-26, OPERATION PROFIT, GROSS -493.80, NET -577.20
# 2018-07-26, Close, 40.48
# 2018-07-27, Close, 40.43
# 2018-07-27, BUY CREATE, 40.43
# 2018-07-30, BUY EXECUTED, Price: 40.32, Cost: 40323.10, Comm 40.32
# 2018-07-30, Close, 39.65
# 2018-07-31, Close, 39.55
# 2018-08-01, Close, 39.23
# 2018-08-02, Close, 39.85
# 2018-08-03, Close, 38.18
# 2018-08-06, Close, 35.52
# 2018-08-06, SELL CREATE, 35.52
# 2018-08-07, SELL EXECUTED, Price: 35.37, Cost: 40323.10, Comm 35.37
# 2018-08-07, OPERATION PROFIT, GROSS -4949.90, NET -5025.60
# 2018-08-07, Close, 36.43
# 2018-08-08, Close, 35.97
# 2018-08-09, Close, 38.50
# 2018-08-10, Close, 40.21
# 2018-08-13, Close, 40.40
# 2018-08-14, Close, 40.83
# 2018-08-15, Close, 38.78
# 2018-08-16, Close, 38.61
# 2018-08-16, BUY CREATE, 38.61
# 2018-08-17, BUY EXECUTED, Price: 38.98, Cost: 38979.40, Comm 38.98
# 2018-08-17, Close, 37.26
# 2018-08-20, Close, 36.12
# 2018-08-21, Close, 38.47
# 2018-08-22, Close, 38.23
# 2018-08-23, Close, 38.80
# 2018-08-24, Close, 39.03
# 2018-08-24, SELL CREATE, 39.03
# 2018-08-27, SELL EXECUTED, Price: 39.17, Cost: 38979.40, Comm 39.17
# 2018-08-27, OPERATION PROFIT, GROSS 195.30, NET 117.15
# 2018-08-27, Close, 40.40
# 2018-08-28, Close, 40.50
# 2018-08-29, Close, 40.06
# 2018-08-30, Close, 39.04
# 2018-08-30, BUY CREATE, 39.04
# 2018-08-31, BUY EXECUTED, Price: 38.76, Cost: 38761.20, Comm 38.76
# 2018-08-31, Close, 37.99
# 2018-09-03, Close, 37.72
# 2018-09-04, Close, 37.74
# 2018-09-05, Close, 37.20
# 2018-09-06, Close, 36.52
# 2018-09-07, Close, 37.68
# 2018-09-07, SELL CREATE, 37.68
# 2018-09-10, SELL EXECUTED, Price: 37.78, Cost: 38761.20, Comm 37.78
# 2018-09-10, OPERATION PROFIT, GROSS -976.20, NET -1052.75
# 2018-09-10, Close, 36.74
# 2018-09-11, Close, 37.17
# 2018-09-12, Close, 35.26
# 2018-09-13, Close, 33.82
# 2018-09-13, BUY CREATE, 33.82
# 2018-09-14, BUY EXECUTED, Price: 33.75, Cost: 33753.80, Comm 33.75
# 2018-09-14, Close, 33.38
# 2018-09-17, Close, 31.81
# 2018-09-18, Close, 33.00
# 2018-09-19, Close, 33.97
# 2018-09-20, Close, 33.99
# 2018-09-21, Close, 34.93
# 2018-09-21, SELL CREATE, 34.93
# 2018-09-25, SELL EXECUTED, Price: 34.48, Cost: 33753.80, Comm 34.48
# 2018-09-25, OPERATION PROFIT, GROSS 723.60, NET 655.37
# 2018-09-25, Close, 35.32
# 2018-09-26, Close, 36.00
# 2018-09-27, Close, 36.03
# 2018-09-28, Close, 36.46
# 2018-10-08, Close, 33.53
# 2018-10-09, Close, 33.75
# 2018-10-10, Close, 33.39
# 2018-10-11, Close, 31.90
# 2018-10-11, BUY CREATE, 31.90
# 2018-10-12, BUY EXECUTED, Price: 32.06, Cost: 32059.80, Comm 32.06
# 2018-10-12, Close, 32.90
# 2018-10-15, Close, 33.07
# 2018-10-16, Close, 33.31
# 2018-10-17, Close, 33.38
# 2018-10-18, Close, 31.84
# 2018-10-19, Close, 32.50
# 2018-10-19, SELL CREATE, 32.50
# 2018-10-22, SELL EXECUTED, Price: 33.02, Cost: 32059.80, Comm 33.02
# 2018-10-22, OPERATION PROFIT, GROSS 959.00, NET 893.92
# 2018-10-22, Close, 35.15
# 2018-10-23, Close, 34.66
# 2018-10-24, Close, 33.63
# 2018-10-24, BUY CREATE, 33.63
# 2018-10-25, BUY EXECUTED, Price: 32.27, Cost: 32272.30, Comm 32.27
# 2018-10-25, Close, 32.62
# 2018-10-26, Close, 33.19
# 2018-10-29, Close, 32.45
# 2018-10-30, Close, 33.52
# 2018-10-31, Close, 35.36
# 2018-11-01, Close, 35.89
# 2018-11-01, SELL CREATE, 35.89
# 2018-11-02, SELL EXECUTED, Price: 37.61, Cost: 32272.30, Comm 37.61
# 2018-11-02, OPERATION PROFIT, GROSS 5340.40, NET 5270.51
# 2018-11-02, Close, 38.82
# 2018-11-05, Close, 37.89
# 2018-11-06, Close, 37.56
# 2018-11-06, BUY CREATE, 37.56
# 2018-11-07, BUY EXECUTED, Price: 37.73, Cost: 37727.60, Comm 37.73
# 2018-11-07, Close, 37.25
# 2018-11-08, Close, 37.49
# 2018-11-09, Close, 37.02
# 2018-11-12, Close, 37.34
# 2018-11-13, Close, 37.56
# 2018-11-14, Close, 36.83
# 2018-11-14, SELL CREATE, 36.83
# 2018-11-15, SELL EXECUTED, Price: 36.52, Cost: 37727.60, Comm 36.52
# 2018-11-15, OPERATION PROFIT, GROSS -1205.90, NET -1280.15
# 2018-11-15, Close, 36.88
# 2018-11-16, Close, 35.78
# 2018-11-19, Close, 36.36
# 2018-11-20, Close, 35.97
# 2018-11-21, Close, 36.76
# 2018-11-22, Close, 36.36
# 2018-11-23, Close, 35.96
# 2018-11-23, BUY CREATE, 35.96
# 2018-11-26, BUY EXECUTED, Price: 36.17, Cost: 36171.40, Comm 36.17
# 2018-11-26, Close, 35.92
# 2018-11-27, Close, 35.90
# 2018-11-28, Close, 37.02
# 2018-11-29, Close, 36.77
# 2018-11-30, Close, 37.58
# 2018-12-03, Close, 38.44
# 2018-12-03, SELL CREATE, 38.44
# 2018-12-04, SELL EXECUTED, Price: 38.47, Cost: 36171.40, Comm 38.47
# 2018-12-04, OPERATION PROFIT, GROSS 2296.90, NET 2222.26
# 2018-12-04, Close, 38.45
# 2018-12-05, Close, 38.42
# 2018-12-06, Close, 35.98
# 2018-12-06, BUY CREATE, 35.98
# 2018-12-07, BUY EXECUTED, Price: 35.37, Cost: 35373.20, Comm 35.37
# 2018-12-07, Close, 33.52
# 2018-12-10, Close, 33.88
# 2018-12-11, Close, 34.52
# 2018-12-12, Close, 33.79
# 2018-12-13, Close, 34.41
# 2018-12-14, Close, 33.82
# 2018-12-14, SELL CREATE, 33.82
# 2018-12-17, SELL EXECUTED, Price: 33.55, Cost: 35373.20, Comm 33.55
# 2018-12-17, OPERATION PROFIT, GROSS -1826.10, NET -1895.02
# 2018-12-17, Close, 32.84
# 2018-12-17, BUY CREATE, 32.84
# 2018-12-18, BUY EXECUTED, Price: 32.78, Cost: 32777.60, Comm 32.78
# 2018-12-18, Close, 32.63
# 2018-12-19, Close, 31.65
# 2018-12-20, Close, 30.41
# 2018-12-21, Close, 28.76
# 2018-12-24, Close, 30.53
# 2018-12-25, Close, 30.67
# 2018-12-25, SELL CREATE, 30.67
# 2018-12-26, SELL EXECUTED, Price: 30.61, Cost: 32777.60, Comm 30.61
# 2018-12-26, OPERATION PROFIT, GROSS -2164.90, NET -2228.29
# 2018-12-26, Close, 29.86
# 2018-12-27, Close, 29.57
# 2018-12-27, BUY CREATE, 29.57
# 2018-12-28, BUY EXECUTED, Price: 29.84, Cost: 29837.50, Comm 29.84
# 2018-12-28, Close, 30.29
# 2019-01-02, Close, 30.42
# 2019-01-03, Close, 29.33
# 2019-01-04, Close, 31.21
# 2019-01-07, Close, 30.76
# 2019-01-08, Close, 31.00
# 2019-01-08, SELL CREATE, 31.00
# 2019-01-09, SELL EXECUTED, Price: 31.30, Cost: 29837.50, Comm 31.30
# 2019-01-09, OPERATION PROFIT, GROSS 1458.60, NET 1397.47
# 2019-01-09, Close, 31.89
# 2019-01-10, Close, 32.31
# 2019-01-11, Close, 32.13
# 2019-01-14, Close, 31.20
# 2019-01-14, BUY CREATE, 31.20
# 2019-01-15, BUY EXECUTED, Price: 31.30, Cost: 31296.10, Comm 31.30
# 2019-01-15, Close, 32.41
# 2019-01-16, Close, 33.00
# 2019-01-17, Close, 32.94
# 2019-01-18, Close, 33.98
# 2019-01-21, Close, 33.92
# 2019-01-22, Close, 33.13
# 2019-01-22, SELL CREATE, 33.13
# 2019-01-23, SELL EXECUTED, Price: 32.96, Cost: 31296.10, Comm 32.96
# 2019-01-23, OPERATION PROFIT, GROSS 1665.30, NET 1601.04
# 2019-01-23, Close, 33.32
# 2019-01-24, Close, 34.10
# 2019-01-25, Close, 33.87
# 2019-01-28, Close, 31.48
# 2019-01-28, BUY CREATE, 31.48
# 2019-01-29, BUY EXECUTED, Price: 31.59, Cost: 31588.90, Comm 31.59
# 2019-01-29, Close, 32.84
# 2019-01-30, Close, 32.96
# 2019-01-31, Close, 33.91
# 2019-02-01, Close, 34.93
# 2019-02-11, Close, 35.52
# 2019-02-12, Close, 36.46
# 2019-02-12, SELL CREATE, 36.46
# 2019-02-13, SELL EXECUTED, Price: 36.75, Cost: 31588.90, Comm 36.75
# 2019-02-13, OPERATION PROFIT, GROSS 5162.50, NET 5094.16
# 2019-02-13, Close, 37.66
# 2019-02-14, Close, 37.78
# 2019-02-15, Close, 36.92
# 2019-02-18, Close, 38.38
# 2019-02-19, Close, 37.86
# 2019-02-20, Close, 37.30
# 2019-02-20, BUY CREATE, 37.30
# 2019-02-21, BUY EXECUTED, Price: 37.36, Cost: 37360.10, Comm 37.36
# 2019-02-21, Close, 37.58
# 2019-02-22, Close, 38.07
# 2019-02-25, Close, 39.34
# 2019-02-26, Close, 39.05
# 2019-02-27, Close, 39.51
# 2019-02-28, Close, 41.29
# 2019-02-28, SELL CREATE, 41.29
# 2019-03-01, SELL EXECUTED, Price: 41.80, Cost: 37360.10, Comm 41.80
# 2019-03-01, OPERATION PROFIT, GROSS 4444.60, NET 4365.44
# 2019-03-01, Close, 41.35
# 2019-03-04, Close, 41.50
# 2019-03-05, Close, 41.41
# 2019-03-06, Close, 40.91
# 2019-03-06, BUY CREATE, 40.91
# 2019-03-07, BUY EXECUTED, Price: 40.91, Cost: 40908.90, Comm 40.91
# 2019-03-07, Close, 40.41
# 2019-03-08, Close, 40.00
# 2019-03-11, Close, 40.37
# 2019-03-12, Close, 40.09
# 2019-03-13, Close, 40.13
# 2019-03-14, Close, 40.23
# 2019-03-14, SELL CREATE, 40.23
# 2019-03-15, SELL EXECUTED, Price: 40.37, Cost: 40908.90, Comm 40.37
# 2019-03-15, OPERATION PROFIT, GROSS -539.80, NET -621.08
# 2019-03-15, Close, 41.07
# 2019-03-18, Close, 42.55
# 2019-03-19, Close, 41.40
# 2019-03-20, Close, 41.76
# 2019-03-21, Close, 41.58
# 2019-03-22, Close, 41.99
# 2019-03-25, Close, 40.89
# 2019-03-26, Close, 41.09
# 2019-03-27, Close, 42.70
# 2019-03-28, Close, 44.68
# 2019-03-29, Close, 45.22
# 2019-04-01, Close, 45.44
# 2019-04-02, Close, 45.12
# 2019-04-03, Close, 45.33
# 2019-04-04, Close, 45.71
# 2019-04-08, Close, 44.22
# 2019-04-09, Close, 44.80
# 2019-04-10, Close, 45.43
# 2019-04-11, Close, 44.22
# 2019-04-12, Close, 44.66
# 2019-04-15, Close, 43.79
# 2019-04-16, Close, 44.83
# 2019-04-17, Close, 44.60
# 2019-04-18, Close, 44.32
# 2019-04-18, BUY CREATE, 44.32
# 2019-04-19, BUY EXECUTED, Price: 44.23, Cost: 44234.70, Comm 44.23
# 2019-04-19, Close, 44.55
# 2019-04-22, Close, 42.95
# 2019-04-23, Close, 43.43
# 2019-04-24, Close, 43.44
# 2019-04-25, Close, 44.17
# 2019-04-26, Close, 43.08
# 2019-04-26, SELL CREATE, 43.08
# 2019-04-29, SELL EXECUTED, Price: 43.18, Cost: 44234.70, Comm 43.18
# 2019-04-29, OPERATION PROFIT, GROSS -1050.60, NET -1138.02
# 2019-04-29, Close, 45.15
# 2019-04-30, Close, 45.44
# 2019-05-06, Close, 44.37
# 2019-05-07, Close, 45.71
# 2019-05-08, Close, 44.39
# 2019-05-09, Close, 43.20
# 2019-05-09, BUY CREATE, 43.20
# 2019-05-10, BUY EXECUTED, Price: 43.81, Cost: 43806.10, Comm 43.81
# 2019-05-10, Close, 44.32
# 2019-05-13, Close, 44.35
# 2019-05-14, Close, 43.56
# 2019-05-15, Close, 45.21
# 2019-05-16, Close, 44.43
# 2019-05-17, Close, 43.38
# 2019-05-17, SELL CREATE, 43.38
# 2019-05-20, SELL EXECUTED, Price: 43.34, Cost: 43806.10, Comm 43.34
# 2019-05-20, OPERATION PROFIT, GROSS -470.00, NET -557.14
# 2019-05-20, Close, 41.64
# 2019-05-20, BUY CREATE, 41.64
# 2019-05-21, BUY EXECUTED, Price: 41.65, Cost: 41649.70, Comm 41.65
# 2019-05-21, Close, 42.03
# 2019-05-22, Close, 42.20
# 2019-05-23, Close, 41.20
# 2019-05-24, Close, 41.52
# 2019-05-27, Close, 42.30
# 2019-05-28, Close, 43.21
# 2019-05-28, SELL CREATE, 43.21
# 2019-05-29, SELL EXECUTED, Price: 42.85, Cost: 41649.70, Comm 42.85
# 2019-05-29, OPERATION PROFIT, GROSS 1202.60, NET 1118.10
# 2019-05-29, Close, 42.79
# 2019-05-30, Close, 42.79
# 2019-05-31, Close, 42.96
# 2019-06-03, Close, 43.70
# 2019-06-04, Close, 42.87
# 2019-06-05, Close, 40.78
# 2019-06-05, BUY CREATE, 40.78
# 2019-06-06, BUY EXECUTED, Price: 40.81, Cost: 40813.40, Comm 40.81
# 2019-06-06, Close, 40.07
# 2019-06-10, Close, 40.52
# 2019-06-11, Close, 41.55
# 2019-06-12, Close, 41.71
# 2019-06-13, Close, 42.37
# 2019-06-14, Close, 42.35
# 2019-06-14, SELL CREATE, 42.35
# 2019-06-17, SELL EXECUTED, Price: 42.82, Cost: 40813.40, Comm 42.82
# 2019-06-17, OPERATION PROFIT, GROSS 2004.40, NET 1920.77
# 2019-06-17, Close, 42.58
# 2019-06-18, Close, 43.26
# 2019-06-19, Close, 44.50
# 2019-06-20, Close, 45.28
# 2019-06-21, Close, 45.55
# 2019-06-24, Close, 45.66
# 2019-06-25, Close, 45.64
# 2019-06-26, Close, 45.96
# 2019-06-27, Close, 46.24
# 2019-06-28, Close, 45.62
# 2019-07-01, Close, 47.16
# 2019-07-02, Close, 48.53
# 2019-07-03, Close, 47.26
# 2019-07-04, Close, 45.69
# 2019-07-04, BUY CREATE, 45.69
# 2019-07-05, BUY EXECUTED, Price: 45.86, Cost: 45858.90, Comm 45.86
# 2019-07-05, Close, 46.58
# 2019-07-08, Close, 45.96
# 2019-07-09, Close, 45.95
# 2019-07-10, Close, 46.59
# 2019-07-11, Close, 46.07
# 2019-07-12, Close, 45.93
# 2019-07-12, SELL CREATE, 45.93
# 2019-07-15, SELL EXECUTED, Price: 46.23, Cost: 45858.90, Comm 46.23
# 2019-07-15, OPERATION PROFIT, GROSS 373.20, NET 281.11
# 2019-07-15, Close, 46.57
# 2019-07-16, Close, 45.66
# 2019-07-17, Close, 45.78
# 2019-07-18, Close, 45.63
# 2019-07-19, Close, 45.63
# 2019-07-22, Close, 45.99
# 2019-07-23, Close, 45.65
# 2019-07-24, Close, 46.03
# 2019-07-25, Close, 46.11
# 2019-07-26, Close, 46.18
# 2019-07-29, Close, 46.07
# 2019-07-30, Close, 46.28
# 2019-07-31, Close, 46.27
# 2019-08-01, Close, 46.12
# 2019-08-01, BUY CREATE, 46.12
# 2019-08-02, BUY EXECUTED, Price: 45.43, Cost: 45430.40, Comm 45.43
# 2019-08-02, Close, 45.64
# 2019-08-05, Close, 44.30
# 2019-08-06, Close, 44.75
# 2019-08-07, Close, 45.27
# 2019-08-08, Close, 46.07
# 2019-08-09, Close, 46.23
# 2019-08-09, SELL CREATE, 46.23
# 2019-08-12, SELL EXECUTED, Price: 46.12, Cost: 45430.40, Comm 46.12
# 2019-08-12, OPERATION PROFIT, GROSS 691.10, NET 599.55
# 2019-08-12, Close, 46.48
# 2019-08-13, Close, 46.35
# 2019-08-14, Close, 47.48
# 2019-08-15, Close, 47.69
# 2019-08-16, Close, 47.77
# 2019-08-19, Close, 49.72
# 2019-08-20, Close, 49.74
# 2019-08-21, Close, 49.56
# 2019-08-22, Close, 49.58
# 2019-08-23, Close, 52.94
# 2019-08-26, Close, 52.22
# 2019-08-27, Close, 52.39
# 2019-08-28, Close, 53.30
# 2019-08-29, Close, 53.18
# 2019-08-30, Close, 55.33
# 2019-09-02, Close, 55.02
# 2019-09-03, Close, 54.26
# 2019-09-03, BUY CREATE, 54.26
# 2019-09-04, BUY EXECUTED, Price: 54.45, Cost: 54450.10, Comm 54.45
# 2019-09-04, Close, 54.10
# 2019-09-05, Close, 54.24
# 2019-09-06, Close, 55.37
# 2019-09-09, Close, 54.77
# 2019-09-10, Close, 55.69
# 2019-09-11, Close, 53.97
# 2019-09-11, SELL CREATE, 53.97
# 2019-09-12, SELL EXECUTED, Price: 54.24, Cost: 54450.10, Comm 54.24
# 2019-09-12, OPERATION PROFIT, GROSS -207.30, NET -315.99
# 2019-09-12, Close, 54.33
# 2019-09-16, Close, 55.13
# 2019-09-17, Close, 54.62
# 2019-09-18, Close, 55.16
# 2019-09-19, Close, 55.39
# 2019-09-20, Close, 56.33
# 2019-09-23, Close, 56.05
# 2019-09-24, Close, 57.02
# 2019-09-25, Close, 57.25
# 2019-09-26, Close, 56.20
# 2019-09-27, Close, 56.02
# 2019-09-27, BUY CREATE, 56.02
# 2019-09-30, BUY EXECUTED, Price: 55.85, Cost: 55846.30, Comm 55.85
# 2019-09-30, Close, 55.76
# 2019-10-08, Close, 55.54
# 2019-10-09, Close, 54.39
# 2019-10-10, Close, 57.37
# 2019-10-11, Close, 57.64
# 2019-10-14, Close, 57.75
# 2019-10-14, SELL CREATE, 57.75
# 2019-10-15, SELL EXECUTED, Price: 58.18, Cost: 55846.30, Comm 58.18
# 2019-10-15, OPERATION PROFIT, GROSS 2329.20, NET 2215.18
# 2019-10-15, Close, 58.92
# 2019-10-16, Close, 59.42
# 2019-10-17, Close, 59.30
# 2019-10-18, Close, 58.24
# 2019-10-18, BUY CREATE, 58.24
# 2019-10-21, BUY EXECUTED, Price: 58.24, Cost: 58237.70, Comm 58.24
# 2019-10-21, Close, 57.10
# 2019-10-22, Close, 57.84
# 2019-10-23, Close, 57.21
# 2019-10-24, Close, 57.17
# 2019-10-25, Close, 60.50
# 2019-10-28, Close, 62.95
# 2019-10-28, SELL CREATE, 62.95
# 2019-10-29, SELL EXECUTED, Price: 62.75, Cost: 58237.70, Comm 62.75
# 2019-10-29, OPERATION PROFIT, GROSS 4513.30, NET 4392.31
# 2019-10-29, Close, 62.73
# 2019-10-30, Close, 62.33
# 2019-10-30, BUY CREATE, 62.33
# 2019-10-31, BUY EXECUTED, Price: 62.90, Cost: 62896.20, Comm 62.90
# 2019-10-31, Close, 62.81
# 2019-11-01, Close, 63.93
# 2019-11-04, Close, 63.73
# 2019-11-05, Close, 63.10
# 2019-11-06, Close, 63.03
# 2019-11-07, Close, 62.61
# 2019-11-07, SELL CREATE, 62.61
# 2019-11-08, SELL EXECUTED, Price: 63.24, Cost: 62896.20, Comm 63.24
# 2019-11-08, OPERATION PROFIT, GROSS 345.50, NET 219.36
# 2019-11-08, Close, 63.10
# 2019-11-11, Close, 61.43
# 2019-11-12, Close, 61.98
# 2019-11-13, Close, 63.17
# 2019-11-14, Close, 65.20
# 2019-11-15, Close, 64.07
# 2019-11-18, Close, 64.21
# 2019-11-19, Close, 66.10
# 2019-11-20, Close, 65.66
# 2019-11-21, Close, 64.00
# 2019-11-21, BUY CREATE, 64.00
# 2019-11-22, BUY EXECUTED, Price: 64.28, Cost: 64278.50, Comm 64.28
# 2019-11-22, Close, 61.50
# 2019-11-25, Close, 60.91
# 2019-11-26, Close, 61.44
# 2019-11-27, Close, 61.96
# 2019-11-28, Close, 61.98
# 2019-11-29, Close, 59.37
# 2019-11-29, SELL CREATE, 59.37
# 2019-12-02, SELL EXECUTED, Price: 57.42, Cost: 64278.50, Comm 57.42
# 2019-12-02, OPERATION PROFIT, GROSS -6856.40, NET -6978.10
# 2019-12-02, Close, 57.87
# 2019-12-02, BUY CREATE, 57.87
# 2019-12-03, BUY EXECUTED, Price: 57.70, Cost: 57698.60, Comm 57.70
# 2019-12-03, Close, 58.44
# 2019-12-04, Close, 59.20
# 2019-12-05, Close, 59.38
# 2019-12-06, Close, 60.20
# 2019-12-09, Close, 57.80
# 2019-12-10, Close, 58.40
# 2019-12-10, SELL CREATE, 58.40
# 2019-12-11, SELL EXECUTED, Price: 58.94, Cost: 57698.60, Comm 58.94
# 2019-12-11, OPERATION PROFIT, GROSS 1244.10, NET 1127.46
# 2019-12-11, Close, 58.75
# 2019-12-12, Close, 58.82
# 2019-12-13, Close, 60.03
# 2019-12-16, Close, 58.92
# 2019-12-17, Close, 59.47
# 2019-12-18, Close, 58.58
# 2019-12-19, Close, 58.65
# 2019-12-20, Close, 58.68
# 2019-12-23, Close, 58.91
# 2019-12-24, Close, 58.40
# 2019-12-25, Close, 57.63
# 2019-12-25, BUY CREATE, 57.63
# 2019-12-26, BUY EXECUTED, Price: 57.71, Cost: 57712.40, Comm 57.71
# 2019-12-26, Close, 58.32
# 2019-12-27, Close, 58.32
# 2019-12-30, Close, 59.09
# 2019-12-31, Close, 60.49
# 2020-01-02, Close, 60.60
# 2020-01-03, Close, 59.41
# 2020-01-03, SELL CREATE, 59.41
# 2020-01-06, SELL EXECUTED, Price: 59.13, Cost: 57712.40, Comm 59.13
# 2020-01-06, OPERATION PROFIT, GROSS 1416.90, NET 1300.06
# 2020-01-06, Close, 58.12
# 2020-01-06, BUY CREATE, 58.12
# 2020-01-07, BUY EXECUTED, Price: 58.13, Cost: 58127.10, Comm 58.13
# 2020-01-07, Close, 58.66
# 2020-01-08, Close, 58.53
# 2020-01-09, Close, 60.05
# 2020-01-10, Close, 60.48
# 2020-01-13, Close, 60.71
# 2020-01-14, Close, 59.79
# 2020-01-14, SELL CREATE, 59.79
# 2020-01-15, SELL EXECUTED, Price: 59.89, Cost: 58127.10, Comm 59.89
# 2020-01-15, OPERATION PROFIT, GROSS 1762.50, NET 1644.48
# 2020-01-15, Close, 60.08
# 2020-01-16, Close, 59.74
# 2020-01-17, Close, 62.66
# 2020-01-20, Close, 62.27
# 2020-01-21, Close, 62.46
# 2020-01-22, Close, 62.43
# 2020-01-23, Close, 60.82
# 2020-01-23, BUY CREATE, 60.82
# 2020-02-03, BUY EXECUTED, Price: 55.69, Cost: 55694.20, Comm 55.69
# 2020-02-03, Close, 59.07
# 2020-02-04, Close, 59.96
# 2020-02-05, Close, 61.45
# 2020-02-06, Close, 62.27
# 2020-02-07, Close, 61.96
# 2020-02-10, Close, 61.17
# 2020-02-10, SELL CREATE, 61.17
# 2020-02-11, SELL EXECUTED, Price: 61.51, Cost: 55694.20, Comm 61.51
# 2020-02-11, OPERATION PROFIT, GROSS 5819.60, NET 5702.39
# 2020-02-11, Close, 62.31
# 2020-02-12, Close, 64.25
# 2020-02-13, Close, 63.21
# 2020-02-14, Close, 63.28
# 2020-02-17, Close, 63.85
# 2020-02-18, Close, 62.62
# 2020-02-19, Close, 61.98
# 2020-02-19, BUY CREATE, 61.98
# 2020-02-20, BUY EXECUTED, Price: 62.33, Cost: 62329.40, Comm 62.33
# 2020-02-20, Close, 62.76
# 2020-02-21, Close, 62.34
# 2020-02-24, Close, 61.09
# 2020-02-25, Close, 61.04
# 2020-02-26, Close, 59.91
# 2020-02-27, Close, 60.28
# 2020-02-27, SELL CREATE, 60.28
# 2020-02-28, SELL EXECUTED, Price: 59.44, Cost: 62329.40, Comm 59.44
# 2020-02-28, OPERATION PROFIT, GROSS -2889.10, NET -3010.87
# 2020-02-28, Close, 58.12
# 2020-03-02, Close, 58.89
# 2020-03-03, Close, 61.06
# 2020-03-04, Close, 60.68
# 2020-03-05, Close, 63.38
# 2020-03-06, Close, 63.76
# 2020-03-09, Close, 61.44
# 2020-03-10, Close, 62.62
# 2020-03-11, Close, 61.53
# 2020-03-12, Close, 59.70
# 2020-03-12, BUY CREATE, 59.70
# 2020-03-13, BUY EXECUTED, Price: 56.81, Cost: 56813.90, Comm 56.81
# 2020-03-13, Close, 58.54
# 2020-03-16, Close, 56.71
# 2020-03-17, Close, 56.05
# 2020-03-18, Close, 55.71
# 2020-03-19, Close, 54.60
# 2020-03-20, Close, 55.40
# 2020-03-20, SELL CREATE, 55.40
# 2020-03-23, SELL EXECUTED, Price: 55.29, Cost: 56813.90, Comm 55.29
# 2020-03-23, OPERATION PROFIT, GROSS -1520.60, NET -1632.71
# 2020-03-23, Close, 56.88
# 2020-03-24, Close, 59.21
# 2020-03-25, Close, 61.49
# 2020-03-26, Close, 62.40
# 2020-03-27, Close, 62.82
# 2020-03-30, Close, 62.69
# 2020-03-31, Close, 63.61
# 2020-04-01, Close, 62.20
# 2020-04-02, Close, 63.48
# 2020-04-03, Close, 64.78
# 2020-04-07, Close, 66.01
# 2020-04-08, Close, 65.51
# 2020-04-09, Close, 66.90
# 2020-04-10, Close, 66.50
# 2020-04-13, Close, 66.82
# 2020-04-14, Close, 68.07
# 2020-04-15, Close, 67.34
# 2020-04-16, Close, 67.33
# 2020-04-16, BUY CREATE, 67.33
# 2020-04-17, BUY EXECUTED, Price: 67.42, Cost: 67423.30, Comm 67.42
# 2020-04-17, Close, 66.77
# 2020-04-20, Close, 66.84
# 2020-04-21, Close, 65.87
# 2020-04-22, Close, 67.39
# 2020-04-23, Close, 66.39
# 2020-04-24, Close, 65.85
# 2020-04-24, SELL CREATE, 65.85
# 2020-04-27, SELL EXECUTED, Price: 66.28, Cost: 67423.30, Comm 66.28
# 2020-04-27, OPERATION PROFIT, GROSS -1140.40, NET -1274.11
# 2020-04-27, Close, 66.59
# ...
# 2020-05-13, SELL EXECUTED, Price: 65.96, Cost: 64555.00, Comm 65.96
# 2020-05-13, OPERATION PROFIT, GROSS 1409.90, NET 1279.38
# 2020-05-13, Close, 66.14
# 2020-05-14, Close, 67.18
# 2020-05-15, Close, 65.54
# 2020-05-18, Close, 67.18
# 2020-05-19, Close, 67.69
# 2020-05-20, Close, 67.67
# 2020-05-21, Close, 68.94
# 2020-05-22, Close, 66.27
# 2020-05-25, Close, 67.30
# 2020-05-26, Close, 67.76
# 2020-05-27, Close, 66.40
# 2020-05-28, Close, 65.26
# 2020-05-28, BUY CREATE, 65.26
# 2020-05-29, BUY EXECUTED, Price: 64.93, Cost: 64930.20, Comm 64.93
# 2020-05-29, Close, 65.43
# 2020-06-01, Close, 66.69
# 2020-06-02, Close, 66.84
# 2020-06-03, Close, 66.65
# 2020-06-04, Close, 67.51
# 2020-06-05, Close, 68.42
# 2020-06-05, SELL CREATE, 68.42
# 2020-06-08, SELL EXECUTED, Price: 68.60, Cost: 64930.20, Comm 68.60
# 2020-06-08, OPERATION PROFIT, GROSS 3674.70, NET 3541.16
# 2020-06-08, Close, 66.76
# 2020-06-09, Close, 68.98
# 2020-06-10, Close, 70.28
# 2020-06-11, Close, 70.22
# 2020-06-12, Close, 71.36
# 2020-06-15, Close, 70.03
# 2020-06-16, Close, 72.45
# 2020-06-17, Close, 74.53
# 2020-06-18, Close, 74.24
# 2020-06-19, Close, 77.30
# 2020-06-22, Close, 77.51
# 2020-06-23, Close, 78.56
# 2020-06-24, Close, 77.28
# 2020-06-29, Close, 76.68
# 2020-06-29, BUY CREATE, 76.68
# 2020-06-30, BUY EXECUTED, Price: 77.22, Cost: 77217.90, Comm 77.22
# 2020-06-30, Close, 76.74
# 2020-07-01, Close, 75.70
# 2020-07-02, Close, 75.82
# 2020-07-03, Close, 76.39
# 2020-07-06, Close, 77.43
# 2020-07-07, Close, 80.88
# 2020-07-07, SELL CREATE, 80.88
# 2020-07-08, SELL EXECUTED, Price: 81.45, Cost: 77217.90, Comm 81.45
# 2020-07-08, OPERATION PROFIT, GROSS 4231.70, NET 4073.03
# 2020-07-08, Close, 80.69
# 2020-07-09, Close, 81.90
# 2020-07-10, Close, 82.60
# 2020-07-13, Close, 82.99
# 2020-07-14, Close, 81.83
# 2020-07-15, Close, 85.62
# 2020-07-16, Close, 80.10
# 2020-07-17, Close, 80.09
# 2020-07-17, BUY CREATE, 80.09
# 2020-07-20, BUY EXECUTED, Price: 80.19, Cost: 80194.20, Comm 80.19
# 2020-07-20, Close, 80.22
# 2020-07-21, Close, 82.56
# 2020-07-22, Close, 82.61
# 2020-07-23, Close, 82.61
# 2020-07-24, Close, 78.81
# 2020-07-27, Close, 79.30
# 2020-07-27, SELL CREATE, 79.30
# 2020-07-28, SELL EXECUTED, Price: 79.31, Cost: 80194.20, Comm 79.31
# 2020-07-28, OPERATION PROFIT, GROSS -881.30, NET -1040.81
# 2020-07-28, Close, 78.65
# 2020-07-29, Close, 79.69
# 2020-07-30, Close, 78.96
# 2020-07-31, Close, 78.46
# 2020-07-31, BUY CREATE, 78.46
# 2020-08-03, BUY EXECUTED, Price: 77.07, Cost: 77068.20, Comm 77.07
# 2020-08-03, Close, 77.48
# 2020-08-04, Close, 78.13
# 2020-08-05, Close, 77.14
# 2020-08-06, Close, 75.65
# 2020-08-07, Close, 75.82
# 2020-08-10, Close, 75.48
# 2020-08-10, SELL CREATE, 75.48
# 2020-08-11, SELL EXECUTED, Price: 76.05, Cost: 77068.20, Comm 76.05
# 2020-08-11, OPERATION PROFIT, GROSS -1022.50, NET -1175.61
# 2020-08-11, Close, 76.30
# 2020-08-12, Close, 74.83
# 2020-08-13, Close, 73.89
# 2020-08-13, BUY CREATE, 73.89
# 2020-08-14, BUY EXECUTED, Price: 73.98, Cost: 73975.50, Comm 73.98
# 2020-08-14, Close, 74.41
# 2020-08-17, Close, 75.57
# 2020-08-18, Close, 77.65
# 2020-08-19, Close, 77.09
# 2020-08-20, Close, 76.24
# 2020-08-21, Close, 76.32
# 2020-08-21, SELL CREATE, 76.32
# 2020-08-24, SELL EXECUTED, Price: 77.30, Cost: 73975.50, Comm 77.30
# 2020-08-24, OPERATION PROFIT, GROSS 3325.50, NET 3174.22
# 2020-08-24, Close, 76.84
# 2020-08-25, Close, 78.14
# 2020-08-26, Close, 78.63
# 2020-08-27, Close, 78.24
# 2020-08-28, Close, 79.30
# 2020-08-31, Close, 78.87
# 2020-09-01, Close, 78.14
# 2020-09-01, BUY CREATE, 78.14
# 2020-09-02, BUY EXECUTED, Price: 78.98, Cost: 78980.40, Comm 78.98
# 2020-09-02, Close, 78.73
# 2020-09-03, Close, 78.98
# 2020-09-04, Close, 77.74
# 2020-09-07, Close, 76.15
# 2020-09-08, Close, 76.76
# 2020-09-09, Close, 75.07
# 2020-09-09, SELL CREATE, 75.07
# 2020-09-10, SELL EXECUTED, Price: 76.07, Cost: 78980.40, Comm 76.07
# 2020-09-10, OPERATION PROFIT, GROSS -2909.80, NET -3064.85
# 2020-09-10, Close, 75.44
# 2020-09-11, Close, 76.33
# 2020-09-14, Close, 75.95
# 2020-09-15, Close, 75.74
# 2020-09-15, BUY CREATE, 75.74
# 2020-09-16, BUY EXECUTED, Price: 75.99, Cost: 75987.50, Comm 75.99
# 2020-09-16, Close, 74.61
# 2020-09-17, Close, 71.74
# 2020-09-18, Close, 73.98
# 2020-09-21, Close, 73.58
# 2020-09-22, Close, 74.24
# 2020-09-23, Close, 74.69
# 2020-09-23, SELL CREATE, 74.69
# 2020-09-24, SELL EXECUTED, Price: 74.45, Cost: 75987.50, Comm 74.45
# 2020-09-24, OPERATION PROFIT, GROSS -1538.10, NET -1688.54
# 2020-09-24, Close, 73.04
# 2020-09-25, Close, 73.53
# 2020-09-28, Close, 73.64
# 2020-09-29, Close, 74.73
# 2020-09-30, Close, 74.67
# 2020-10-09, Close, 76.44
# 2020-10-12, Close, 78.32
# 2020-10-13, Close, 77.90
# 2020-10-14, Close, 77.32
# 2020-10-14, BUY CREATE, 77.32
# 2020-10-15, BUY EXECUTED, Price: 77.32, Cost: 77317.70, Comm 77.32
# 2020-10-15, Close, 77.45
# 2020-10-16, Close, 77.40
# 2020-10-19, Close, 76.09
# 2020-10-20, Close, 75.66
# 2020-10-21, Close, 74.47
# 2020-10-22, Close, 74.46
# 2020-10-22, SELL CREATE, 74.46
# 2020-10-23, SELL EXECUTED, Price: 74.46, Cost: 77317.70, Comm 74.46
# 2020-10-23, OPERATION PROFIT, GROSS -2860.00, NET -3011.78
# 2020-10-23, Close, 73.29
# 2020-10-23, BUY CREATE, 73.29
# 2020-10-26, BUY EXECUTED, Price: 73.24, Cost: 73243.90, Comm 73.24
# 2020-10-26, Close, 74.14
# 2020-10-27, Close, 74.18
# 2020-10-28, Close, 75.95
# 2020-10-29, Close, 75.69
# 2020-10-30, Close, 73.86
# 2020-11-02, Close, 74.18
# 2020-11-02, SELL CREATE, 74.18
# 2020-11-03, SELL EXECUTED, Price: 74.35, Cost: 73243.90, Comm 74.35
# 2020-11-03, OPERATION PROFIT, GROSS 1105.80, NET 958.21
# 2020-11-03, Close, 74.95
# 2020-11-04, Close, 74.96
# 2020-11-05, Close, 75.82
# 2020-11-06, Close, 73.90
# 2020-11-09, Close, 74.30
# 2020-11-10, Close, 73.12
# 2020-11-11, Close, 71.64
# 2020-11-11, BUY CREATE, 71.64
# 2020-11-12, BUY EXECUTED, Price: 71.91, Cost: 71913.70, Comm 71.91
# 2020-11-12, Close, 71.96
# 2020-11-13, Close, 71.08
# 2020-11-16, Close, 71.19
# 2020-11-17, Close, 71.11
# 2020-11-18, Close, 72.01
# 2020-11-19, Close, 72.58
# 2020-11-19, SELL CREATE, 72.58
# 2020-11-20, SELL EXECUTED, Price: 72.58, Cost: 71913.70, Comm 72.58
# 2020-11-20, OPERATION PROFIT, GROSS 665.10, NET 520.61
# 2020-11-20, Close, 72.25
# 2020-11-23, Close, 71.60
# 2020-11-23, BUY CREATE, 71.60
# 2020-11-24, BUY EXECUTED, Price: 71.59, Cost: 71589.50, Comm 71.59
# 2020-11-24, Close, 72.47
# 2020-11-25, Close, 71.61
# 2020-11-26, Close, 71.50
# 2020-11-27, Close, 72.29
# 2020-11-30, Close, 71.49
# 2020-12-01, Close, 72.84
# 2020-12-01, SELL CREATE, 72.84
# 2020-12-02, SELL EXECUTED, Price: 73.00, Cost: 71589.50, Comm 73.00
# 2020-12-02, OPERATION PROFIT, GROSS 1413.30, NET 1268.71
# 2020-12-02, Close, 72.77
# 2020-12-03, Close, 74.82
# 2020-12-04, Close, 75.92
# 2020-12-07, Close, 74.72
# 2020-12-08, Close, 74.88
# 2020-12-09, Close, 73.36
# 2020-12-10, Close, 73.99
# 2020-12-11, Close, 74.41
# 2020-12-14, Close, 74.92
# 2020-12-15, Close, 80.66
# 2020-12-16, Close, 80.65
# 2020-12-17, Close, 87.44
# 2020-12-18, Close, 87.84
# 2020-12-21, Close, 89.67
# 2020-12-22, Close, 88.29
# 2020-12-23, Close, 88.13
# 2020-12-23, BUY CREATE, 88.13
# 2020-12-24, BUY EXECUTED, Price: 88.54, Cost: 88541.20, Comm 88.54
# 2020-12-24, Close, 90.45
# 2020-12-25, Close, 95.62
# 2020-12-28, Close, 92.28
# 2020-12-29, Close, 90.02
# 2020-12-30, Close, 93.70
# 2020-12-31, Close, 92.66
# 2020-12-31, SELL CREATE, 92.66
# 2021-01-04, SELL EXECUTED, Price: 93.11, Cost: 88541.20, Comm 93.11
# 2021-01-04, OPERATION PROFIT, GROSS 4564.20, NET 4382.55
# 2021-01-04, Close, 92.45
# 2021-01-04, BUY CREATE, 92.45
# 2021-01-05, BUY EXECUTED, Price: 92.45, Cost: 92448.60, Comm 92.45
# 2021-01-05, Close, 94.14
# 2021-01-06, Close, 94.54
# 2021-01-07, Close, 95.61
# 2021-01-08, Close, 94.13
# 2021-01-11, Close, 92.53
# 2021-01-12, Close, 94.86
# 2021-01-12, SELL CREATE, 94.86
# 2021-01-13, SELL EXECUTED, Price: 94.78, Cost: 92448.60, Comm 94.78
# 2021-01-13, OPERATION PROFIT, GROSS 2336.20, NET 2148.97
# 2021-01-13, Close, 93.59
# 2021-01-14, Close, 91.60
# 2021-01-14, BUY CREATE, 91.60
# 2021-01-15, BUY EXECUTED, Price: 92.70, Cost: 92698.00, Comm 92.70
# 2021-01-15, Close, 91.31
# 2021-01-18, Close, 89.65
# 2021-01-19, Close, 87.25
# 2021-01-20, Close, 88.10
# 2021-01-21, Close, 89.91
# 2021-01-22, Close, 93.61
# 2021-01-22, SELL CREATE, 93.61
# 2021-01-25, SELL EXECUTED, Price: 93.76, Cost: 92698.00, Comm 93.76
# 2021-01-25, OPERATION PROFIT, GROSS 1064.20, NET 877.74
# 2021-01-25, Close, 92.66
# 2021-01-26, Close, 88.96
# 2021-01-26, BUY CREATE, 88.96
# 2021-01-27, BUY EXECUTED, Price: 89.54, Cost: 89538.80, Comm 89.54
# 2021-01-27, Close, 88.64
# 2021-01-28, Close, 87.01
# 2021-01-29, Close, 86.26
# 2021-02-01, Close, 85.26
# 2021-02-02, Close, 88.13
# 2021-02-03, Close, 87.29
# 2021-02-03, SELL CREATE, 87.29
# 2021-02-04, SELL EXECUTED, Price: 86.46, Cost: 89538.80, Comm 86.46
# 2021-02-04, OPERATION PROFIT, GROSS -3076.00, NET -3252.00
# 2021-02-04, Close, 85.47
# 2021-02-04, BUY CREATE, 85.47
# 2021-02-05, BUY EXECUTED, Price: 86.42, Cost: 86421.20, Comm 86.42
# 2021-02-05, Close, 89.21
# 2021-02-08, Close, 88.36
# 2021-02-09, Close, 91.23
# 2021-02-10, Close, 90.79
# 2021-02-18, Close, 87.21
# 2021-02-19, Close, 87.43
# 2021-02-19, SELL CREATE, 87.43
# 2021-02-22, SELL EXECUTED, Price: 88.46, Cost: 86421.20, Comm 88.46
# 2021-02-22, OPERATION PROFIT, GROSS 2036.80, NET 1861.92
# 2021-02-22, Close, 83.15
# 2021-02-23, Close, 83.72
# 2021-02-24, Close, 82.89
# 2021-02-25, Close, 84.01
# 2021-02-26, Close, 84.63
# 2021-03-01, Close, 83.39
# 2021-03-02, Close, 81.77
# 2021-03-02, BUY CREATE, 81.77
# 2021-03-03, BUY EXECUTED, Price: 81.89, Cost: 81890.20, Comm 81.89
# 2021-03-03, Close, 84.26
# 2021-03-04, Close, 83.55
# 2021-03-05, Close, 83.39
# 2021-03-08, Close, 76.59
# 2021-03-09, Close, 76.30
# 2021-03-10, Close, 77.65
# 2021-03-10, SELL CREATE, 77.65
# 2021-03-11, SELL EXECUTED, Price: 78.14, Cost: 81890.20, Comm 78.14
# 2021-03-11, OPERATION PROFIT, GROSS -3749.50, NET -3909.53
# 2021-03-11, Close, 77.72
# 2021-03-12, Close, 76.64
# 2021-03-15, Close, 74.48
# 2021-03-15, BUY CREATE, 74.48
# 2021-03-16, BUY EXECUTED, Price: 75.24, Cost: 75239.20, Comm 75.24
# 2021-03-16, Close, 74.15
# 2021-03-17, Close, 73.68
# 2021-03-18, Close, 74.17
# 2021-03-19, Close, 73.20
# 2021-03-22, Close, 73.25
# 2021-03-23, Close, 72.87
# 2021-03-23, SELL CREATE, 72.87
# 2021-03-24, SELL EXECUTED, Price: 72.87, Cost: 75239.20, Comm 72.87
# 2021-03-24, OPERATION PROFIT, GROSS -2369.40, NET -2517.51
# 2021-03-24, Close, 71.93
# 2021-03-24, BUY CREATE, 71.93
# 2021-03-25, BUY EXECUTED, Price: 71.25, Cost: 71248.60, Comm 71.25
# 2021-03-25, Close, 72.52
# 2021-03-26, Close, 75.84
# 2021-03-29, Close, 75.26
# 2021-03-30, Close, 77.82
# 2021-03-31, Close, 76.56
# 2021-04-01, Close, 78.02
# 2021-04-01, SELL CREATE, 78.02
# 2021-04-02, SELL EXECUTED, Price: 78.15, Cost: 71248.60, Comm 78.15
# 2021-04-02, OPERATION PROFIT, GROSS 6900.40, NET 6751.00
# 2021-04-02, Close, 77.05
# 2021-04-06, Close, 75.57
# 2021-04-06, BUY CREATE, 75.57
# 2021-04-07, BUY EXECUTED, Price: 75.82, Cost: 75821.20, Comm 75.82
# 2021-04-07, Close, 75.39
# 2021-04-08, Close, 76.85
# 2021-04-09, Close, 75.82
# 2021-04-12, Close, 74.43
# 2021-04-13, Close, 73.98
# 2021-04-14, Close, 71.10
# 2021-04-14, SELL CREATE, 71.10
# 2021-04-15, SELL EXECUTED, Price: 70.27, Cost: 75821.20, Comm 70.27
# 2021-04-15, OPERATION PROFIT, GROSS -5553.60, NET -5699.69
# 2021-04-15, Close, 68.32
# 2021-04-15, BUY CREATE, 68.32
# 2021-04-16, BUY EXECUTED, Price: 68.46, Cost: 68463.50, Comm 68.46
# 2021-04-16, Close, 67.03
# 2021-04-19, Close, 68.25
# 2021-04-20, Close, 66.77
# 2021-04-21, Close, 69.15
# 2021-04-22, Close, 68.34
# 2021-04-23, Close, 69.00
# 2021-04-23, SELL CREATE, 69.00
# 2021-04-26, SELL EXECUTED, Price: 69.15, Cost: 68463.50, Comm 69.15
# 2021-04-26, OPERATION PROFIT, GROSS 690.10, NET 552.48
# 2021-04-26, Close, 67.77
# 2021-04-27, Close, 69.05
# 2021-04-28, Close, 68.89
# 2021-04-29, Close, 68.46
# 2021-04-29, BUY CREATE, 68.46
# 2021-04-30, BUY EXECUTED, Price: 69.00, Cost: 69003.90, Comm 69.00
# 2021-04-30, Close, 69.92
# 2021-05-06, Close, 68.27
# 2021-05-07, Close, 66.50
# 2021-05-10, Close, 66.78
# 2021-05-11, Close, 69.59
# 2021-05-12, Close, 69.15
# 2021-05-12, SELL CREATE, 69.15
# 2021-05-13, SELL EXECUTED, Price: 68.69, Cost: 69003.90, Comm 68.69
# 2021-05-13, OPERATION PROFIT, GROSS -315.90, NET -453.59
# 2021-05-13, Close, 67.95
# 2021-05-13, BUY CREATE, 67.95
# 2021-05-14, BUY EXECUTED, Price: 68.43, Cost: 68430.30, Comm 68.43
# 2021-05-14, Close, 69.69
# 2021-05-17, Close, 70.98
# 2021-05-18, Close, 71.27
# 2021-05-19, Close, 70.71
# 2021-05-20, Close, 69.59
# 2021-05-21, Close, 68.31
# 2021-05-21, SELL CREATE, 68.31
# 2021-05-24, SELL EXECUTED, Price: 68.10, Cost: 68430.30, Comm 68.10
# 2021-05-24, OPERATION PROFIT, GROSS -332.60, NET -469.13
# 2021-05-24, Close, 69.30
# 2021-05-25, Close, 71.71
# 2021-05-26, Close, 71.74
# 2021-05-27, Close, 71.76
# 2021-05-28, Close, 71.37
# 2021-05-31, Close, 71.75
# 2021-06-01, Close, 72.72
# 2021-06-02, Close, 70.13
# 2021-06-03, Close, 68.65
# 2021-06-03, BUY CREATE, 68.65
# 2021-06-04, BUY EXECUTED, Price: 68.23, Cost: 68230.80, Comm 68.23
# 2021-06-04, Close, 68.71
# 2021-06-07, Close, 68.54
# 2021-06-08, Close, 68.99
# 2021-06-09, Close, 69.96
# 2021-06-10, Close, 73.00
# 2021-06-11, Close, 72.96
# 2021-06-11, SELL CREATE, 72.96
# 2021-06-15, SELL EXECUTED, Price: 72.96, Cost: 68230.80, Comm 72.96
# 2021-06-15, OPERATION PROFIT, GROSS 4729.20, NET 4588.01
# 2021-06-15, Close, 71.88
# 2021-06-15, BUY CREATE, 71.88
# 2021-06-16, BUY EXECUTED, Price: 71.88, Cost: 71880.00, Comm 71.88
# 2021-06-16, Close, 70.81
# 2021-06-17, Close, 71.15
# 2021-06-18, Close, 71.44
# 2021-06-21, Close, 69.51
# 2021-06-22, Close, 70.48
# 2021-06-23, Close, 71.15
# 2021-06-23, SELL CREATE, 71.15
# 2021-06-24, SELL EXECUTED, Price: 69.99, Cost: 71880.00, Comm 69.99
# 2021-06-24, OPERATION PROFIT, GROSS -1890.00, NET -2031.87
# 2021-06-24, Close, 68.00
# 2021-06-25, Close, 68.06
# 2021-06-28, Close, 68.60
# 2021-06-29, Close, 68.20
# 2021-06-30, Close, 67.97
# 2021-06-30, BUY CREATE, 67.97
# 2021-07-01, BUY EXECUTED, Price: 68.00, Cost: 68000.00, Comm 68.00
# 2021-07-01, Close, 69.69
# 2021-07-02, Close, 66.91
# 2021-07-05, Close, 62.95
# 2021-07-06, Close, 62.06
# 2021-07-07, Close, 62.45
# 2021-07-08, Close, 61.37
# 2021-07-08, SELL CREATE, 61.37
# 2021-07-09, SELL EXECUTED, Price: 61.02, Cost: 68000.00, Comm 61.02
# 2021-07-09, OPERATION PROFIT, GROSS -6980.00, NET -7109.02
# 2021-07-09, Close, 62.10
# 2021-07-12, Close, 63.12
# 2021-07-13, Close, 61.94
# 2021-07-14, Close, 60.11
# 2021-07-14, BUY CREATE, 60.11
# 2021-07-15, BUY EXECUTED, Price: 59.80, Cost: 59800.00, Comm 59.80
# 2021-07-15, Close, 60.27
# 2021-07-16, Close, 60.10
# 2021-07-19, Close, 60.96
# 2021-07-20, Close, 63.18
# 2021-07-21, Close, 62.98
# 2021-07-22, Close, 61.28
# 2021-07-22, SELL CREATE, 61.28
# 2021-07-23, SELL EXECUTED, Price: 61.19, Cost: 59800.00, Comm 61.19
# 2021-07-23, OPERATION PROFIT, GROSS 1390.00, NET 1269.01
# 2021-07-23, Close, 61.49
# 2021-07-26, Close, 59.22
# 2021-07-27, Close, 54.50
# 2021-07-27, BUY CREATE, 54.50
# 2021-07-28, BUY EXECUTED, Price: 53.97, Cost: 53970.00, Comm 53.97
# 2021-07-28, Close, 55.91
# 2021-07-29, Close, 55.11
# 2021-07-30, Close, 54.38
# 2021-08-02, Close, 55.25
# 2021-08-03, Close, 57.40
# 2021-08-04, Close, 56.33
# 2021-08-04, SELL CREATE, 56.33
# 2021-08-05, SELL EXECUTED, Price: 56.34, Cost: 53970.00, Comm 56.34
# 2021-08-05, OPERATION PROFIT, GROSS 2370.00, NET 2259.69
# 2021-08-05, Close, 55.80
# 2021-08-05, BUY CREATE, 55.80
# 2021-08-06, BUY EXECUTED, Price: 55.50, Cost: 55500.00, Comm 55.50
# 2021-08-06, Close, 54.80
# 2021-08-09, Close, 56.92
# 2021-08-10, Close, 57.74
# 2021-08-11, Close, 56.89
# 2021-08-12, Close, 55.80
# 2021-08-13, Close, 56.53
# 2021-08-13, SELL CREATE, 56.53
# 2021-08-16, SELL EXECUTED, Price: 56.53, Cost: 55500.00, Comm 56.53
# 2021-08-16, OPERATION PROFIT, GROSS 1030.00, NET 917.97
# 2021-08-16, Close, 56.47
# 2021-08-17, Close, 54.75
# 2021-08-17, BUY CREATE, 54.75
# 2021-08-18, BUY EXECUTED, Price: 54.82, Cost: 54820.00, Comm 54.82
# 2021-08-18, Close, 54.99
# 2021-08-19, Close, 53.84
# 2021-08-20, Close, 48.46
# 2021-08-23, Close, 47.18
# 2021-08-24, Close, 47.20
# 2021-08-25, Close, 47.41
# 2021-08-25, SELL CREATE, 47.41
# 2021-08-26, SELL EXECUTED, Price: 47.01, Cost: 54820.00, Comm 47.01
# 2021-08-26, OPERATION PROFIT, GROSS -7810.00, NET -7911.83
# 2021-08-26, Close, 45.31
# 2021-08-27, Close, 46.05
# 2021-08-30, Close, 45.60
# 2021-08-31, Close, 45.20
# 2021-08-31, BUY CREATE, 45.20
# 2021-09-01, BUY EXECUTED, Price: 45.40, Cost: 45400.00, Comm 45.40
# 2021-09-01, Close, 46.59
# 2021-09-02, Close, 45.86
# 2021-09-03, Close, 46.10
# 2021-09-06, Close, 48.10
# Final Portfolio Value: 133540.17

# %% [markdown]
# ## 策略：均线策略

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):
    # 设定参数，便于修改
    params = (
        ('maperiod', 60),
    )

    def log(self, txt, dt=None):
        ''' 
        日志函数：打印结果
        datas[0]：传入的数据，包含日期、OHLC等数据
        datas[0].datetime.date(0)：调用传入数据中的日期列
        '''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # dataclose变量：跟踪当前收盘价
        self.dataclose = self.datas[0].close

        # order变量：跟踪订单状态
        self.order = None
        # buyprice变量：买入价格
        self.buyprice = None
        # buycomm变量：买入时佣金费用
        self.buycomm = None

        # 指标：简单移动平均 MovingAverageSimple【15天】
        self.sma = bt.indicators.SimpleMovingAverage(self.datas[0], 
                                                     period=self.params.maperiod)
        
        # 添加画图专用指标
        bt.indicators.ExponentialMovingAverage(self.datas[0], period=25)
        bt.indicators.WeightedMovingAverage(self.datas[0], period=25,subplot=True)
        bt.indicators.StochasticSlow(self.datas[0])
        bt.indicators.MACDHisto(self.datas[0])
        rsi = bt.indicators.RSI(self.datas[0])
        bt.indicators.SmoothedMovingAverage(rsi, period=10)
        bt.indicators.ATR(self.datas[0], plot=False)

    def notify_order(self, order):
        '''订单状态通知(order.status)：提示成交状态'''
        if order.status in [order.Submitted, order.Accepted]:
            # 如果订单只是提交状态，那么啥也不提示
            return

        # 检查订单是否执行完毕
        # 注意：如果剩余现金不足，则会被拒绝！
        if order.status in [order.Completed]:
            if order.isbuy():
                # 买入信号记录：买入价、买入费用、买入佣金费用
                self.log(
                        'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                        (order.executed.price,
                         order.executed.value,
                         order.executed.comm))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            elif order.issell():
                # 卖出信号记录：卖出价、卖出费用、卖出佣金费用
                self.log(
                        'SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                        (order.executed.price,
                         order.executed.value,
                         order.executed.comm))
            
            # 记录订单执行的价格柱的编号（即长度）
            self.bar_executed = len(self)

        # 如果订单被取消/保证金不足/被拒绝
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # 如果没有查询到订单，则订单为None
        self.order = None

    def notify_trade(self, trade):
        '''交易状态通知：查看交易毛/净利润'''
        if not trade.isclosed:
            return
        # 交易毛利润：trade.pnl、交易净利润：trade.pnlcomm（扣除佣金）
        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                    (trade.pnl, trade.pnlcomm))


    # 交易策略主函数
    def next(self):
        # 记录收盘价
        self.log('Close, %.2f' % self.dataclose[0])

        # 检查一下是否有订单被挂起，如果有的话就先不下单
        if self.order:
            return
        
        # 检查一下目前是否持有头寸，如果没有就建仓
        # 策略：价格连续跌3天就买
        if not self.position:

            # 如果现价>【15日】均线
            if self.dataclose[0] > self.sma[0]:
                # 买买买！先记录一下买入价格（收盘价）
                self.log('BUY CREATE, %.2f' % self.dataclose[0])
                # 更新订单状态：buy()：开仓买入，买入价是下一个数据，即【开盘价】
                self.order = self.buy()
        else:
             # 如果已经建仓，并持有头寸，则执行卖出指令
             # 如果现价<【15日】均线
            if self.dataclose[0] < self.sma[0]:
                # 卖!卖!卖!
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                # 更新订单状态：sell()：平仓卖出，卖出价是下一个数据，即【开盘价】
                self.order = self.sell()

# 创建实例
cerebro = bt.Cerebro()

 # 添加策略
cerebro.addstrategy(TestStrategy)

# 添加数据源
data = bt.feeds.PandasData(dataname=df)

# 输入数据源
cerebro.adddata(data)

# 设置初始现金：10万
cerebro.broker.setcash(100000.0)

# 设定每次买入的股票数量：10股
cerebro.addsizer(bt.sizers.FixedSize, stake=1000)

# 设置佣金费率：双边0.1%
cerebro.broker.setcommission(commission=0.001)

# 显示：初始资产
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

# 运行策略
cerebro.run()

# 显示：最终资产
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

# 画出图像
cerebro.plot(volume=False)
# Out:
# Starting Portfolio Value: 100000.00
# 2016-04-01, Close, 14.50
# 2016-04-01, BUY CREATE, 14.50
# 2016-04-05, BUY EXECUTED, Price: 14.40, Cost: 14395.30, Comm 14.40
# 2016-04-05, Close, 14.61
# 2016-04-06, Close, 14.51
# 2016-04-07, Close, 14.55
# 2016-04-08, Close, 14.44
# 2016-04-11, Close, 14.34
# 2016-04-13, Close, 14.37
# 2016-04-14, Close, 14.40
# 2016-04-15, Close, 14.53
# 2016-04-18, Close, 14.68
# 2016-04-19, Close, 14.57
# 2016-04-20, Close, 14.59
# 2016-04-21, Close, 14.26
# 2016-04-22, Close, 14.29
# 2016-04-25, Close, 14.19
# 2016-04-26, Close, 14.44
# 2016-04-27, Close, 14.43
# 2016-04-28, Close, 14.26
# 2016-04-29, Close, 14.24
# 2016-04-29, SELL CREATE, 14.24
# 2016-05-03, SELL EXECUTED, Price: 14.30, Cost: 14395.30, Comm 14.30
# 2016-05-03, OPERATION PROFIT, GROSS -97.60, NET -126.29
# 2016-05-03, Close, 14.58
# 2016-05-03, BUY CREATE, 14.58
# 2016-05-04, BUY EXECUTED, Price: 14.55, Cost: 14547.80, Comm 14.55
# 2016-05-04, Close, 14.58
# 2016-05-05, Close, 14.50
# 2016-05-06, Close, 14.31
# 2016-05-06, SELL CREATE, 14.31
# 2016-05-09, SELL EXECUTED, Price: 14.24, Cost: 14547.80, Comm 14.24
# 2016-05-09, OPERATION PROFIT, GROSS -305.00, NET -333.79
# 2016-05-09, Close, 14.14
# 2016-05-10, Close, 14.13
# 2016-05-11, Close, 14.41
# 2016-05-11, BUY CREATE, 14.41
# 2016-05-12, BUY EXECUTED, Price: 14.33, Cost: 14334.30, Comm 14.33
# 2016-05-12, Close, 14.31
# 2016-05-12, SELL CREATE, 14.31
# 2016-05-13, SELL EXECUTED, Price: 14.23, Cost: 14334.30, Comm 14.23
# 2016-05-13, OPERATION PROFIT, GROSS -103.70, NET -132.26
# 2016-05-13, Close, 14.28
# 2016-05-16, Close, 14.34
# 2016-05-17, Close, 14.44
# 2016-05-17, BUY CREATE, 14.44
# 2016-05-18, BUY EXECUTED, Price: 14.34, Cost: 14340.40, Comm 14.34
# 2016-05-18, Close, 14.38
# 2016-05-19, Close, 14.22
# 2016-05-19, SELL CREATE, 14.22
# 2016-05-20, SELL EXECUTED, Price: 14.16, Cost: 14340.40, Comm 14.16
# 2016-05-20, OPERATION PROFIT, GROSS -180.00, NET -208.50
# 2016-05-20, Close, 14.18
# 2016-05-23, Close, 14.00
# 2016-05-24, Close, 14.00
# 2016-05-25, Close, 13.79
# 2016-05-26, Close, 13.77
# 2016-05-27, Close, 13.68
# 2016-05-30, Close, 13.72
# 2016-05-31, Close, 14.01
# 2016-06-01, Close, 13.94
# 2016-06-02, Close, 13.89
# 2016-06-03, Close, 14.25
# 2016-06-06, Close, 14.21
# 2016-06-07, Close, 14.19
# 2016-06-08, Close, 14.24
# 2016-06-13, Close, 14.06
# 2016-06-14, Close, 14.00
# 2016-06-15, Close, 14.09
# 2016-06-16, Close, 14.27
# 2016-06-17, Close, 14.43
# 2016-06-17, BUY CREATE, 14.43
# 2016-06-20, BUY EXECUTED, Price: 14.43, Cost: 14427.40, Comm 14.43
# 2016-06-20, Close, 14.37
# 2016-06-21, Close, 14.38
# 2016-06-22, Close, 14.59
# 2016-06-23, Close, 14.63
# 2016-06-24, Close, 14.44
# 2016-06-27, Close, 14.81
# 2016-06-28, Close, 14.87
# 2016-06-29, Close, 14.78
# 2016-06-30, Close, 14.71
# 2016-07-01, Close, 14.78
# 2016-07-04, Close, 14.97
# 2016-07-05, Close, 14.87
# 2016-07-06, Close, 14.97
# 2016-07-07, Close, 15.03
# 2016-07-08, Close, 14.87
# 2016-07-11, Close, 15.43
# 2016-07-12, Close, 15.86
# 2016-07-13, Close, 15.80
# 2016-07-14, Close, 15.73
# 2016-07-15, Close, 15.84
# 2016-07-18, Close, 15.94
# 2016-07-19, Close, 15.65
# 2016-07-20, Close, 15.70
# 2016-07-21, Close, 15.64
# 2016-07-22, Close, 15.45
# 2016-07-25, Close, 15.72
# 2016-07-26, Close, 15.74
# 2016-07-27, Close, 15.82
# 2016-07-28, Close, 16.06
# 2016-07-29, Close, 16.02
# 2016-08-01, Close, 15.83
# 2016-08-02, Close, 16.06
# 2016-08-03, Close, 16.07
# 2016-08-04, Close, 15.96
# 2016-08-05, Close, 16.08
# 2016-08-08, Close, 16.02
# 2016-08-09, Close, 16.47
# 2016-08-10, Close, 16.40
# 2016-08-11, Close, 16.35
# 2016-08-12, Close, 16.42
# 2016-08-15, Close, 16.62
# 2016-08-16, Close, 16.61
# 2016-08-17, Close, 16.46
# 2016-08-18, Close, 16.32
# 2016-08-19, Close, 16.31
# 2016-08-22, Close, 16.36
# 2016-08-23, Close, 16.20
# 2016-08-24, Close, 16.17
# 2016-08-25, Close, 16.18
# 2016-08-26, Close, 16.19
# 2016-08-29, Close, 16.28
# 2016-08-30, Close, 15.86
# 2016-08-31, Close, 15.89
# 2016-09-01, Close, 15.97
# 2016-09-02, Close, 16.33
# 2016-09-05, Close, 16.18
# 2016-09-06, Close, 16.19
# 2016-09-07, Close, 16.02
# 2016-09-08, Close, 15.95
# 2016-09-09, Close, 15.84
# 2016-09-12, Close, 16.09
# 2016-09-13, Close, 15.98
# 2016-09-14, Close, 15.65
# 2016-09-14, SELL CREATE, 15.65
# 2016-09-19, SELL EXECUTED, Price: 15.65, Cost: 14427.40, Comm 15.65
# 2016-09-19, OPERATION PROFIT, GROSS 1224.90, NET 1194.82
# 2016-09-19, Close, 15.84
# 2016-09-19, BUY CREATE, 15.84
# 2016-09-20, BUY EXECUTED, Price: 15.86, Cost: 15857.70, Comm 15.86
# 2016-09-20, Close, 15.95
# 2016-09-21, Close, 15.97
# 2016-09-22, Close, 16.03
# 2016-09-23, Close, 16.31
# 2016-09-26, Close, 16.08
# 2016-09-27, Close, 16.02
# 2016-09-28, Close, 16.05
# 2016-09-29, Close, 16.10
# 2016-09-30, Close, 16.15
# 2016-10-10, Close, 16.58
# 2016-10-11, Close, 16.81
# 2016-10-12, Close, 16.74
# 2016-10-13, Close, 16.92
# 2016-10-14, Close, 16.84
# 2016-10-17, Close, 17.18
# 2016-10-18, Close, 17.16
# 2016-10-19, Close, 17.27
# 2016-10-20, Close, 17.07
# 2016-10-21, Close, 17.09
# 2016-10-24, Close, 16.98
# 2016-10-25, Close, 16.87
# 2016-10-26, Close, 17.06
# 2016-10-27, Close, 17.09
# 2016-10-28, Close, 16.95
# 2016-10-31, Close, 16.92
# 2016-11-01, Close, 17.20
# 2016-11-02, Close, 17.15
# 2016-11-03, Close, 17.08
# 2016-11-04, Close, 16.78
# 2016-11-07, Close, 16.65
# 2016-11-08, Close, 16.97
# 2016-11-09, Close, 16.95
# 2016-11-10, Close, 16.83
# 2016-11-11, Close, 16.74
# 2016-11-14, Close, 16.55
# 2016-11-15, Close, 16.61
# 2016-11-16, Close, 16.81
# 2016-11-17, Close, 16.82
# 2016-11-18, Close, 16.70
# 2016-11-21, Close, 16.82
# 2016-11-22, Close, 16.98
# 2016-11-23, Close, 16.91
# 2016-11-24, Close, 17.10
# 2016-11-25, Close, 17.09
# 2016-11-28, Close, 17.00
# 2016-11-29, Close, 17.00
# 2016-11-30, Close, 17.19
# 2016-12-01, Close, 17.19
# 2016-12-02, Close, 17.25
# 2016-12-05, Close, 17.27
# 2016-12-06, Close, 17.55
# 2016-12-07, Close, 17.54
# 2016-12-08, Close, 17.34
# 2016-12-09, Close, 17.20
# 2016-12-12, Close, 17.36
# 2016-12-13, Close, 17.16
# 2016-12-14, Close, 17.14
# 2016-12-15, Close, 17.05
# 2016-12-16, Close, 17.09
# 2016-12-19, Close, 17.15
# 2016-12-20, Close, 16.83
# 2016-12-20, SELL CREATE, 16.83
# 2016-12-21, SELL EXECUTED, Price: 16.76, Cost: 15857.70, Comm 16.76
# 2016-12-21, OPERATION PROFIT, GROSS 905.80, NET 873.18
# 2016-12-21, Close, 16.90
# 2016-12-22, Close, 16.62
# 2016-12-23, Close, 16.62
# 2016-12-26, Close, 16.77
# 2016-12-27, Close, 16.84
# 2016-12-28, Close, 16.68
# 2016-12-29, Close, 16.69
# 2016-12-30, Close, 16.69
# 2017-01-03, Close, 16.87
# 2017-01-04, Close, 17.08
# 2017-01-04, BUY CREATE, 17.08
# 2017-01-05, BUY EXECUTED, Price: 17.07, Cost: 17067.90, Comm 17.07
# 2017-01-05, Close, 17.09
# 2017-01-06, Close, 16.87
# 2017-01-06, SELL CREATE, 16.87
# 2017-01-09, SELL EXECUTED, Price: 16.84, Cost: 17067.90, Comm 16.84
# 2017-01-09, OPERATION PROFIT, GROSS -231.10, NET -265.00
# 2017-01-09, Close, 16.71
# 2017-01-10, Close, 16.88
# 2017-01-11, Close, 16.60
# 2017-01-12, Close, 16.60
# 2017-01-13, Close, 16.75
# 2017-01-16, Close, 17.05
# 2017-01-16, BUY CREATE, 17.05
# 2017-01-17, BUY EXECUTED, Price: 16.94, Cost: 16943.20, Comm 16.94
# 2017-01-17, Close, 16.98
# 2017-01-18, Close, 17.06
# 2017-01-19, Close, 17.22
# 2017-01-20, Close, 17.24
# 2017-01-23, Close, 17.46
# 2017-01-24, Close, 17.18
# 2017-01-25, Close, 17.52
# 2017-01-26, Close, 17.54
# 2017-02-03, Close, 17.93
# 2017-02-06, Close, 17.71
# 2017-02-07, Close, 17.59
# 2017-02-08, Close, 17.70
# 2017-02-09, Close, 17.66
# 2017-02-10, Close, 17.53
# 2017-02-13, Close, 17.56
# 2017-02-14, Close, 17.72
# 2017-02-15, Close, 17.56
# 2017-02-16, Close, 18.12
# 2017-02-17, Close, 18.00
# 2017-02-20, Close, 18.24
# 2017-02-21, Close, 18.28
# 2017-02-22, Close, 18.32
# 2017-02-23, Close, 18.46
# 2017-02-24, Close, 18.84
# 2017-02-27, Close, 18.63
# 2017-02-28, Close, 18.48
# 2017-03-01, Close, 18.28
# 2017-03-02, Close, 18.19
# 2017-03-03, Close, 18.26
# 2017-03-06, Close, 18.41
# 2017-03-07, Close, 18.76
# 2017-03-08, Close, 18.84
# 2017-03-09, Close, 18.76
# 2017-03-10, Close, 18.81
# 2017-03-13, Close, 18.62
# 2017-03-14, Close, 18.66
# 2017-03-15, Close, 19.16
# 2017-03-16, Close, 19.00
# 2017-03-17, Close, 19.06
# 2017-03-20, Close, 19.22
# 2017-03-21, Close, 19.61
# 2017-03-22, Close, 19.68
# 2017-03-23, Close, 19.67
# 2017-03-24, Close, 19.61
# 2017-03-27, Close, 19.73
# 2017-03-28, Close, 19.75
# 2017-03-29, Close, 19.57
# 2017-03-30, Close, 19.52
# 2017-03-31, Close, 19.92
# 2017-04-05, Close, 19.98
# 2017-04-06, Close, 20.07
# 2017-04-07, Close, 20.11
# 2017-04-10, Close, 19.77
# 2017-04-11, Close, 19.40
# 2017-04-12, Close, 19.57
# 2017-04-13, Close, 19.86
# 2017-04-14, Close, 19.80
# 2017-04-17, Close, 19.87
# 2017-04-18, Close, 20.16
# 2017-04-19, Close, 20.16
# 2017-04-20, Close, 20.46
# 2017-04-21, Close, 20.64
# 2017-04-24, Close, 20.75
# 2017-04-25, Close, 20.68
# 2017-04-26, Close, 20.38
# 2017-04-27, Close, 20.06
# 2017-04-28, Close, 19.67
# 2017-05-02, Close, 19.49
# 2017-05-03, Close, 19.70
# 2017-05-04, Close, 19.95
# 2017-05-05, Close, 20.04
# 2017-05-08, Close, 20.07
# 2017-05-09, Close, 19.94
# 2017-05-10, Close, 20.30
# 2017-05-11, Close, 20.51
# 2017-05-12, Close, 20.52
# 2017-05-15, Close, 20.72
# 2017-05-16, Close, 21.20
# 2017-05-17, Close, 21.07
# 2017-05-18, Close, 21.58
# 2017-05-19, Close, 21.54
# 2017-05-22, Close, 21.75
# 2017-05-23, Close, 22.08
# 2017-05-24, Close, 22.04
# 2017-05-25, Close, 21.49
# 2017-05-26, Close, 21.60
# 2017-05-31, Close, 21.96
# 2017-06-01, Close, 22.39
# 2017-06-02, Close, 22.09
# 2017-06-05, Close, 21.51
# 2017-06-06, Close, 21.83
# 2017-06-07, Close, 22.21
# 2017-06-08, Close, 22.61
# 2017-06-09, Close, 22.56
# 2017-06-12, Close, 22.60
# 2017-06-13, Close, 22.41
# 2017-06-14, Close, 22.42
# 2017-06-15, Close, 22.29
# 2017-06-16, Close, 22.66
# 2017-06-19, Close, 22.18
# 2017-06-20, Close, 21.75
# 2017-06-21, Close, 22.05
# 2017-06-22, Close, 21.84
# 2017-06-23, Close, 22.11
# 2017-06-26, Close, 22.54
# 2017-06-27, Close, 22.54
# 2017-06-28, Close, 22.10
# 2017-06-29, Close, 22.33
# 2017-06-30, Close, 22.32
# 2017-07-03, Close, 22.09
# 2017-07-04, Close, 21.69
# 2017-07-05, Close, 21.95
# 2017-07-06, Close, 21.73
# 2017-07-07, Close, 21.54
# 2017-07-10, Close, 21.76
# 2017-07-11, Close, 21.84
# 2017-07-12, Close, 21.65
# 2017-07-13, Close, 21.66
# 2017-07-14, Close, 21.49
# 2017-07-17, Close, 21.63
# 2017-07-18, Close, 22.11
# 2017-07-19, Close, 22.28
# 2017-07-20, Close, 22.22
# 2017-07-21, Close, 22.02
# 2017-07-24, Close, 22.08
# 2017-07-25, Close, 22.11
# 2017-07-26, Close, 22.16
# 2017-07-27, Close, 22.26
# 2017-07-28, Close, 22.45
# 2017-07-31, Close, 22.59
# 2017-08-01, Close, 22.63
# 2017-08-02, Close, 22.16
# 2017-08-03, Close, 22.10
# 2017-08-04, Close, 22.11
# 2017-08-07, Close, 22.37
# 2017-08-08, Close, 22.38
# 2017-08-09, Close, 23.35
# 2017-08-10, Close, 23.20
# 2017-08-11, Close, 23.44
# 2017-08-14, Close, 24.24
# 2017-08-15, Close, 24.06
# 2017-08-16, Close, 23.85
# 2017-08-17, Close, 23.64
# 2017-08-18, Close, 23.69
# 2017-08-21, Close, 24.17
# 2017-08-22, Close, 23.92
# 2017-08-23, Close, 24.09
# 2017-08-24, Close, 24.17
# 2017-08-25, Close, 24.13
# 2017-08-28, Close, 23.83
# 2017-08-29, Close, 23.82
# 2017-08-30, Close, 23.85
# 2017-08-31, Close, 23.88
# 2017-09-01, Close, 24.56
# 2017-09-04, Close, 25.77
# 2017-09-05, Close, 25.68
# 2017-09-06, Close, 25.39
# 2017-09-07, Close, 25.75
# 2017-09-08, Close, 26.22
# 2017-09-11, Close, 25.77
# 2017-09-12, Close, 25.71
# 2017-09-13, Close, 25.77
# 2017-09-14, Close, 25.47
# 2017-09-15, Close, 25.69
# 2017-09-18, Close, 25.85
# 2017-09-19, Close, 25.92
# 2017-09-20, Close, 25.97
# 2017-09-21, Close, 25.69
# 2017-09-22, Close, 25.65
# 2017-09-25, Close, 25.64
# 2017-09-26, Close, 25.62
# 2017-09-27, Close, 25.78
# 2017-09-28, Close, 26.50
# 2017-09-29, Close, 26.44
# 2017-10-09, Close, 27.33
# 2017-10-10, Close, 26.87
# 2017-10-11, Close, 27.52
# 2017-10-12, Close, 27.76
# 2017-10-13, Close, 27.75
# 2017-10-16, Close, 27.79
# 2017-10-17, Close, 28.15
# 2017-10-18, Close, 28.07
# 2017-10-19, Close, 28.86
# 2017-10-20, Close, 28.66
# 2017-10-23, Close, 28.72
# 2017-10-24, Close, 28.61
# 2017-10-25, Close, 29.47
# 2017-10-26, Close, 29.23
# 2017-10-27, Close, 29.06
# 2017-10-30, Close, 28.68
# 2017-10-31, Close, 29.66
# 2017-11-01, Close, 30.22
# 2017-11-02, Close, 30.47
# 2017-11-03, Close, 31.74
# 2017-11-06, Close, 33.39
# 2017-11-07, Close, 31.89
# 2017-11-08, Close, 31.09
# 2017-11-09, Close, 31.31
# 2017-11-10, Close, 31.55
# 2017-11-13, Close, 30.63
# 2017-11-14, Close, 29.59
# 2017-11-15, Close, 30.04
# 2017-11-16, Close, 30.82
# 2017-11-17, Close, 29.87
# 2017-11-20, Close, 30.40
# 2017-11-21, Close, 30.53
# 2017-11-22, Close, 30.34
# 2017-11-23, Close, 28.63
# 2017-11-24, Close, 28.78
# 2017-11-27, Close, 28.33
# 2017-11-28, Close, 29.22
# 2017-11-29, Close, 28.81
# 2017-11-30, Close, 28.76
# 2017-12-01, Close, 29.15
# 2017-12-04, Close, 29.74
# 2017-12-05, Close, 29.29
# 2017-12-06, Close, 28.84
# 2017-12-07, Close, 28.43
# 2017-12-07, SELL CREATE, 28.43
# 2017-12-08, SELL EXECUTED, Price: 28.38, Cost: 16943.20, Comm 28.38
# 2017-12-08, OPERATION PROFIT, GROSS 11434.30, NET 11388.98
# 2017-12-08, Close, 28.86
# 2017-12-08, BUY CREATE, 28.86
# 2017-12-11, BUY EXECUTED, Price: 29.44, Cost: 29440.60, Comm 29.44
# 2017-12-11, Close, 30.62
# 2017-12-12, Close, 30.34
# 2017-12-13, Close, 30.64
# 2017-12-14, Close, 30.72
# 2017-12-15, Close, 29.80
# 2017-12-18, Close, 30.06
# 2017-12-19, Close, 30.28
# 2017-12-20, Close, 30.61
# 2017-12-21, Close, 31.23
# 2017-12-22, Close, 31.42
# 2017-12-25, Close, 31.32
# 2017-12-26, Close, 31.19
# 2017-12-27, Close, 30.06
# 2017-12-28, Close, 30.62
# 2017-12-29, Close, 30.43
# 2018-01-02, Close, 30.29
# 2018-01-03, Close, 30.36
# 2018-01-04, Close, 31.13
# 2018-01-05, Close, 31.02
# 2018-01-08, Close, 31.43
# 2018-01-09, Close, 32.95
# 2018-01-10, Close, 33.04
# 2018-01-11, Close, 32.76
# 2018-01-12, Close, 32.91
# 2018-01-15, Close, 32.86
# 2018-01-16, Close, 33.13
# 2018-01-17, Close, 32.44
# 2018-01-18, Close, 32.11
# 2018-01-19, Close, 32.80
# 2018-01-22, Close, 33.70
# 2018-01-23, Close, 33.83
# 2018-01-24, Close, 34.44
# 2018-01-25, Close, 33.55
# 2018-01-26, Close, 34.03
# 2018-01-29, Close, 32.31
# 2018-01-30, Close, 32.69
# 2018-01-31, Close, 33.39
# 2018-02-01, Close, 32.74
# 2018-02-02, Close, 32.77
# 2018-02-05, Close, 32.37
# 2018-02-06, Close, 30.44
# 2018-02-06, SELL CREATE, 30.44
# 2018-02-07, SELL EXECUTED, Price: 31.36, Cost: 29440.60, Comm 31.36
# 2018-02-07, OPERATION PROFIT, GROSS 1914.50, NET 1853.70
# 2018-02-07, Close, 29.86
# 2018-02-08, Close, 30.49
# 2018-02-09, Close, 29.80
# 2018-02-12, Close, 31.31
# 2018-02-12, BUY CREATE, 31.31
# 2018-02-13, BUY EXECUTED, Price: 31.57, Cost: 31571.20, Comm 31.57
# 2018-02-13, Close, 31.42
# 2018-02-14, Close, 31.73
# 2018-02-22, Close, 31.97
# 2018-02-23, Close, 32.33
# 2018-02-26, Close, 32.98
# 2018-02-27, Close, 32.50
# 2018-02-28, Close, 31.97
# 2018-03-01, Close, 32.73
# 2018-03-02, Close, 32.54
# 2018-03-05, Close, 32.85
# 2018-03-06, Close, 33.61
# 2018-03-07, Close, 33.26
# 2018-03-08, Close, 34.52
# 2018-03-09, Close, 35.02
# 2018-03-12, Close, 35.28
# 2018-03-13, Close, 34.77
# 2018-03-14, Close, 35.25
# 2018-03-15, Close, 36.48
# 2018-03-16, Close, 36.15
# 2018-03-19, Close, 38.09
# 2018-03-20, Close, 38.59
# 2018-03-21, Close, 38.16
# 2018-03-22, Close, 37.89
# 2018-03-23, Close, 37.33
# 2018-03-26, Close, 38.53
# 2018-03-27, Close, 38.25
# 2018-03-28, Close, 36.72
# 2018-03-29, Close, 36.52
# 2018-03-30, Close, 38.38
# 2018-04-02, Close, 37.44
# 2018-04-03, Close, 37.43
# 2018-04-04, Close, 37.10
# 2018-04-09, Close, 36.44
# 2018-04-10, Close, 37.21
# 2018-04-11, Close, 37.52
# 2018-04-12, Close, 37.82
# 2018-04-13, Close, 35.77
# 2018-04-16, Close, 36.74
# 2018-04-17, Close, 35.67
# 2018-04-18, Close, 36.19
# 2018-04-19, Close, 36.63
# 2018-04-20, Close, 37.07
# 2018-04-23, Close, 37.18
# 2018-04-24, Close, 37.39
# 2018-04-25, Close, 38.58
# 2018-04-26, Close, 36.95
# 2018-04-27, Close, 36.83
# 2018-05-02, Close, 36.14
# 2018-05-03, Close, 36.56
# 2018-05-04, Close, 36.37
# 2018-05-07, Close, 37.28
# 2018-05-08, Close, 37.74
# 2018-05-09, Close, 37.87
# 2018-05-10, Close, 40.40
# 2018-05-11, Close, 39.47
# 2018-05-14, Close, 40.20
# 2018-05-15, Close, 40.77
# 2018-05-16, Close, 40.42
# 2018-05-17, Close, 39.67
# 2018-05-18, Close, 40.70
# 2018-05-21, Close, 40.49
# 2018-05-22, Close, 41.97
# 2018-05-23, Close, 41.76
# 2018-05-24, Close, 41.51
# 2018-05-25, Close, 42.95
# 2018-05-28, Close, 44.67
# 2018-05-29, Close, 42.09
# 2018-05-30, Close, 42.79
# 2018-05-31, Close, 43.72
# 2018-06-01, Close, 42.50
# 2018-06-04, Close, 43.49
# 2018-06-05, Close, 46.03
# 2018-06-06, Close, 47.32
# 2018-06-07, Close, 47.09
# 2018-06-08, Close, 46.60
# 2018-06-11, Close, 44.80
# 2018-06-12, Close, 45.17
# 2018-06-13, Close, 44.23
# 2018-06-14, Close, 43.81
# 2018-06-15, Close, 43.61
# 2018-06-19, Close, 43.06
# 2018-06-20, Close, 45.33
# 2018-06-21, Close, 44.90
# 2018-06-22, Close, 45.35
# 2018-06-25, Close, 45.72
# 2018-06-26, Close, 45.80
# 2018-06-27, Close, 43.90
# 2018-06-28, Close, 41.83
# 2018-06-29, Close, 43.50
# 2018-07-02, Close, 43.30
# 2018-07-03, Close, 41.64
# 2018-07-04, Close, 40.24
# 2018-07-04, SELL CREATE, 40.24
# 2018-07-05, SELL EXECUTED, Price: 40.31, Cost: 31571.20, Comm 40.31
# 2018-07-05, OPERATION PROFIT, GROSS 8740.40, NET 8668.52
# 2018-07-05, Close, 39.04
# 2018-07-06, Close, 40.19
# 2018-07-09, Close, 41.51
# 2018-07-09, BUY CREATE, 41.51
# 2018-07-10, BUY EXECUTED, Price: 41.78, Cost: 41776.00, Comm 41.78
# 2018-07-10, Close, 41.83
# 2018-07-11, Close, 41.56
# 2018-07-12, Close, 42.32
# 2018-07-13, Close, 43.06
# 2018-07-16, Close, 42.90
# 2018-07-17, Close, 41.78
# 2018-07-18, Close, 42.55
# 2018-07-19, Close, 42.05
# 2018-07-20, Close, 42.36
# 2018-07-23, Close, 40.31
# 2018-07-23, SELL CREATE, 40.31
# 2018-07-24, SELL EXECUTED, Price: 40.02, Cost: 41776.00, Comm 40.02
# 2018-07-24, OPERATION PROFIT, GROSS -1751.50, NET -1833.30
# 2018-07-24, Close, 40.78
# 2018-07-25, Close, 41.28
# 2018-07-26, Close, 40.48
# 2018-07-27, Close, 40.43
# 2018-07-30, Close, 39.65
# 2018-07-31, Close, 39.55
# 2018-08-01, Close, 39.23
# 2018-08-02, Close, 39.85
# 2018-08-03, Close, 38.18
# 2018-08-06, Close, 35.52
# 2018-08-07, Close, 36.43
# 2018-08-08, Close, 35.97
# 2018-08-09, Close, 38.50
# 2018-08-10, Close, 40.21
# 2018-08-13, Close, 40.40
# 2018-08-14, Close, 40.83
# 2018-08-15, Close, 38.78
# 2018-08-16, Close, 38.61
# 2018-08-17, Close, 37.26
# 2018-08-20, Close, 36.12
# 2018-08-21, Close, 38.47
# 2018-08-22, Close, 38.23
# 2018-08-23, Close, 38.80
# 2018-08-24, Close, 39.03
# 2018-08-27, Close, 40.40
# 2018-08-28, Close, 40.50
# 2018-08-29, Close, 40.06
# 2018-08-30, Close, 39.04
# 2018-08-31, Close, 37.99
# 2018-09-03, Close, 37.72
# 2018-09-04, Close, 37.74
# 2018-09-05, Close, 37.20
# 2018-09-06, Close, 36.52
# 2018-09-07, Close, 37.68
# 2018-09-10, Close, 36.74
# 2018-09-11, Close, 37.17
# 2018-09-12, Close, 35.26
# 2018-09-13, Close, 33.82
# 2018-09-14, Close, 33.38
# 2018-09-17, Close, 31.81
# 2018-09-18, Close, 33.00
# 2018-09-19, Close, 33.97
# 2018-09-20, Close, 33.99
# 2018-09-21, Close, 34.93
# 2018-09-25, Close, 35.32
# 2018-09-26, Close, 36.00
# 2018-09-27, Close, 36.03
# 2018-09-28, Close, 36.46
# 2018-10-08, Close, 33.53
# 2018-10-09, Close, 33.75
# 2018-10-10, Close, 33.39
# 2018-10-11, Close, 31.90
# 2018-10-12, Close, 32.90
# 2018-10-15, Close, 33.07
# 2018-10-16, Close, 33.31
# 2018-10-17, Close, 33.38
# 2018-10-18, Close, 31.84
# 2018-10-19, Close, 32.50
# 2018-10-22, Close, 35.15
# 2018-10-23, Close, 34.66
# 2018-10-24, Close, 33.63
# 2018-10-25, Close, 32.62
# 2018-10-26, Close, 33.19
# 2018-10-29, Close, 32.45
# 2018-10-30, Close, 33.52
# 2018-10-31, Close, 35.36
# 2018-11-01, Close, 35.89
# 2018-11-02, Close, 38.82
# 2018-11-02, BUY CREATE, 38.82
# 2018-11-05, BUY EXECUTED, Price: 38.26, Cost: 38255.90, Comm 38.26
# 2018-11-05, Close, 37.89
# 2018-11-06, Close, 37.56
# 2018-11-07, Close, 37.25
# 2018-11-08, Close, 37.49
# 2018-11-09, Close, 37.02
# 2018-11-12, Close, 37.34
# 2018-11-13, Close, 37.56
# 2018-11-14, Close, 36.83
# 2018-11-15, Close, 36.88
# 2018-11-16, Close, 35.78
# 2018-11-16, SELL CREATE, 35.78
# 2018-11-19, SELL EXECUTED, Price: 35.88, Cost: 38255.90, Comm 35.88
# 2018-11-19, OPERATION PROFIT, GROSS -2377.40, NET -2451.53
# 2018-11-19, Close, 36.36
# 2018-11-19, BUY CREATE, 36.36
# 2018-11-20, BUY EXECUTED, Price: 36.13, Cost: 36125.40, Comm 36.13
# 2018-11-20, Close, 35.97
# 2018-11-21, Close, 36.76
# 2018-11-22, Close, 36.36
# 2018-11-23, Close, 35.96
# 2018-11-26, Close, 35.92
# 2018-11-27, Close, 35.90
# 2018-11-28, Close, 37.02
# 2018-11-29, Close, 36.77
# 2018-11-30, Close, 37.58
# 2018-12-03, Close, 38.44
# 2018-12-04, Close, 38.45
# 2018-12-05, Close, 38.42
# 2018-12-06, Close, 35.98
# 2018-12-07, Close, 33.52
# 2018-12-07, SELL CREATE, 33.52
# 2018-12-10, SELL EXECUTED, Price: 33.01, Cost: 36125.40, Comm 33.01
# 2018-12-10, OPERATION PROFIT, GROSS -3118.10, NET -3187.23
# 2018-12-10, Close, 33.88
# 2018-12-11, Close, 34.52
# 2018-12-12, Close, 33.79
# 2018-12-13, Close, 34.41
# 2018-12-14, Close, 33.82
# 2018-12-17, Close, 32.84
# 2018-12-18, Close, 32.63
# 2018-12-19, Close, 31.65
# 2018-12-20, Close, 30.41
# 2018-12-21, Close, 28.76
# 2018-12-24, Close, 30.53
# 2018-12-25, Close, 30.67
# 2018-12-26, Close, 29.86
# 2018-12-27, Close, 29.57
# 2018-12-28, Close, 30.29
# 2019-01-02, Close, 30.42
# 2019-01-03, Close, 29.33
# 2019-01-04, Close, 31.21
# 2019-01-07, Close, 30.76
# 2019-01-08, Close, 31.00
# 2019-01-09, Close, 31.89
# 2019-01-10, Close, 32.31
# 2019-01-11, Close, 32.13
# 2019-01-14, Close, 31.20
# 2019-01-15, Close, 32.41
# 2019-01-16, Close, 33.00
# 2019-01-17, Close, 32.94
# 2019-01-18, Close, 33.98
# 2019-01-21, Close, 33.92
# 2019-01-22, Close, 33.13
# 2019-01-23, Close, 33.32
# 2019-01-24, Close, 34.10
# 2019-01-25, Close, 33.87
# 2019-01-28, Close, 31.48
# 2019-01-29, Close, 32.84
# 2019-01-30, Close, 32.96
# 2019-01-31, Close, 33.91
# 2019-02-01, Close, 34.93
# 2019-02-01, BUY CREATE, 34.93
# 2019-02-11, BUY EXECUTED, Price: 34.49, Cost: 34494.60, Comm 34.49
# 2019-02-11, Close, 35.52
# 2019-02-12, Close, 36.46
# 2019-02-13, Close, 37.66
# 2019-02-14, Close, 37.78
# 2019-02-15, Close, 36.92
# 2019-02-18, Close, 38.38
# 2019-02-19, Close, 37.86
# 2019-02-20, Close, 37.30
# 2019-02-21, Close, 37.58
# 2019-02-22, Close, 38.07
# 2019-02-25, Close, 39.34
# 2019-02-26, Close, 39.05
# 2019-02-27, Close, 39.51
# 2019-02-28, Close, 41.29
# 2019-03-01, Close, 41.35
# 2019-03-04, Close, 41.50
# 2019-03-05, Close, 41.41
# 2019-03-06, Close, 40.91
# 2019-03-07, Close, 40.41
# 2019-03-08, Close, 40.00
# 2019-03-11, Close, 40.37
# 2019-03-12, Close, 40.09
# 2019-03-13, Close, 40.13
# 2019-03-14, Close, 40.23
# 2019-03-15, Close, 41.07
# 2019-03-18, Close, 42.55
# 2019-03-19, Close, 41.40
# 2019-03-20, Close, 41.76
# 2019-03-21, Close, 41.58
# 2019-03-22, Close, 41.99
# 2019-03-25, Close, 40.89
# 2019-03-26, Close, 41.09
# 2019-03-27, Close, 42.70
# 2019-03-28, Close, 44.68
# 2019-03-29, Close, 45.22
# 2019-04-01, Close, 45.44
# 2019-04-02, Close, 45.12
# 2019-04-03, Close, 45.33
# 2019-04-04, Close, 45.71
# 2019-04-08, Close, 44.22
# 2019-04-09, Close, 44.80
# 2019-04-10, Close, 45.43
# 2019-04-11, Close, 44.22
# 2019-04-12, Close, 44.66
# 2019-04-15, Close, 43.79
# 2019-04-16, Close, 44.83
# 2019-04-17, Close, 44.60
# 2019-04-18, Close, 44.32
# 2019-04-19, Close, 44.55
# 2019-04-22, Close, 42.95
# 2019-04-23, Close, 43.43
# 2019-04-24, Close, 43.44
# 2019-04-25, Close, 44.17
# 2019-04-26, Close, 43.08
# 2019-04-29, Close, 45.15
# 2019-04-30, Close, 45.44
# 2019-05-06, Close, 44.37
# 2019-05-07, Close, 45.71
# 2019-05-08, Close, 44.39
# 2019-05-09, Close, 43.20
# 2019-05-10, Close, 44.32
# 2019-05-13, Close, 44.35
# 2019-05-14, Close, 43.56
# 2019-05-15, Close, 45.21
# 2019-05-16, Close, 44.43
# 2019-05-17, Close, 43.38
# 2019-05-20, Close, 41.64
# 2019-05-20, SELL CREATE, 41.64
# 2019-05-21, SELL EXECUTED, Price: 41.65, Cost: 34494.60, Comm 41.65
# 2019-05-21, OPERATION PROFIT, GROSS 7155.10, NET 7078.96
# 2019-05-21, Close, 42.03
# 2019-05-22, Close, 42.20
# 2019-05-23, Close, 41.20
# 2019-05-24, Close, 41.52
# 2019-05-27, Close, 42.30
# 2019-05-28, Close, 43.21
# 2019-05-28, BUY CREATE, 43.21
# 2019-05-29, BUY EXECUTED, Price: 42.85, Cost: 42852.30, Comm 42.85
# 2019-05-29, Close, 42.79
# 2019-05-29, SELL CREATE, 42.79
# 2019-05-30, SELL EXECUTED, Price: 42.30, Cost: 42852.30, Comm 42.30
# 2019-05-30, OPERATION PROFIT, GROSS -552.90, NET -638.05
# 2019-05-30, Close, 42.79
# 2019-05-31, Close, 42.96
# 2019-06-03, Close, 43.70
# 2019-06-03, BUY CREATE, 43.70
# 2019-06-04, BUY EXECUTED, Price: 43.79, Cost: 43785.40, Comm 43.79
# 2019-06-04, Close, 42.87
# 2019-06-04, SELL CREATE, 42.87
# 2019-06-05, SELL EXECUTED, Price: 42.85, Cost: 43785.40, Comm 42.85
# 2019-06-05, OPERATION PROFIT, GROSS -933.10, NET -1019.74
# 2019-06-05, Close, 40.78
# 2019-06-06, Close, 40.07
# 2019-06-10, Close, 40.52
# 2019-06-11, Close, 41.55
# 2019-06-12, Close, 41.71
# 2019-06-13, Close, 42.37
# 2019-06-14, Close, 42.35
# 2019-06-17, Close, 42.58
# 2019-06-18, Close, 43.26
# 2019-06-19, Close, 44.50
# 2019-06-19, BUY CREATE, 44.50
# 2019-06-20, BUY EXECUTED, Price: 44.72, Cost: 44718.50, Comm 44.72
# 2019-06-20, Close, 45.28
# 2019-06-21, Close, 45.55
# 2019-06-24, Close, 45.66
# 2019-06-25, Close, 45.64
# 2019-06-26, Close, 45.96
# 2019-06-27, Close, 46.24
# 2019-06-28, Close, 45.62
# 2019-07-01, Close, 47.16
# 2019-07-02, Close, 48.53
# 2019-07-03, Close, 47.26
# 2019-07-04, Close, 45.69
# 2019-07-05, Close, 46.58
# 2019-07-08, Close, 45.96
# 2019-07-09, Close, 45.95
# 2019-07-10, Close, 46.59
# 2019-07-11, Close, 46.07
# 2019-07-12, Close, 45.93
# 2019-07-15, Close, 46.57
# 2019-07-16, Close, 45.66
# 2019-07-17, Close, 45.78
# 2019-07-18, Close, 45.63
# 2019-07-19, Close, 45.63
# 2019-07-22, Close, 45.99
# 2019-07-23, Close, 45.65
# 2019-07-24, Close, 46.03
# 2019-07-25, Close, 46.11
# 2019-07-26, Close, 46.18
# 2019-07-29, Close, 46.07
# 2019-07-30, Close, 46.28
# 2019-07-31, Close, 46.27
# 2019-08-01, Close, 46.12
# 2019-08-02, Close, 45.64
# 2019-08-05, Close, 44.30
# 2019-08-05, SELL CREATE, 44.30
# 2019-08-06, SELL EXECUTED, Price: 43.54, Cost: 44718.50, Comm 43.54
# 2019-08-06, OPERATION PROFIT, GROSS -1175.00, NET -1263.26
# 2019-08-06, Close, 44.75
# 2019-08-06, BUY CREATE, 44.75
# 2019-08-07, BUY EXECUTED, Price: 44.93, Cost: 44925.80, Comm 44.93
# 2019-08-07, Close, 45.27
# 2019-08-08, Close, 46.07
# 2019-08-09, Close, 46.23
# 2019-08-12, Close, 46.48
# 2019-08-13, Close, 46.35
# 2019-08-14, Close, 47.48
# 2019-08-15, Close, 47.69
# 2019-08-16, Close, 47.77
# 2019-08-19, Close, 49.72
# 2019-08-20, Close, 49.74
# 2019-08-21, Close, 49.56
# 2019-08-22, Close, 49.58
# 2019-08-23, Close, 52.94
# 2019-08-26, Close, 52.22
# 2019-08-27, Close, 52.39
# 2019-08-28, Close, 53.30
# 2019-08-29, Close, 53.18
# 2019-08-30, Close, 55.33
# 2019-09-02, Close, 55.02
# 2019-09-03, Close, 54.26
# 2019-09-04, Close, 54.10
# 2019-09-05, Close, 54.24
# 2019-09-06, Close, 55.37
# 2019-09-09, Close, 54.77
# 2019-09-10, Close, 55.69
# 2019-09-11, Close, 53.97
# 2019-09-12, Close, 54.33
# 2019-09-16, Close, 55.13
# 2019-09-17, Close, 54.62
# 2019-09-18, Close, 55.16
# 2019-09-19, Close, 55.39
# 2019-09-20, Close, 56.33
# 2019-09-23, Close, 56.05
# 2019-09-24, Close, 57.02
# 2019-09-25, Close, 57.25
# 2019-09-26, Close, 56.20
# 2019-09-27, Close, 56.02
# 2019-09-30, Close, 55.76
# 2019-10-08, Close, 55.54
# 2019-10-09, Close, 54.39
# 2019-10-10, Close, 57.37
# 2019-10-11, Close, 57.64
# 2019-10-14, Close, 57.75
# 2019-10-15, Close, 58.92
# 2019-10-16, Close, 59.42
# 2019-10-17, Close, 59.30
# 2019-10-18, Close, 58.24
# 2019-10-21, Close, 57.10
# 2019-10-22, Close, 57.84
# 2019-10-23, Close, 57.21
# 2019-10-24, Close, 57.17
# 2019-10-25, Close, 60.50
# 2019-10-28, Close, 62.95
# 2019-10-29, Close, 62.73
# 2019-10-30, Close, 62.33
# 2019-10-31, Close, 62.81
# 2019-11-01, Close, 63.93
# 2019-11-04, Close, 63.73
# 2019-11-05, Close, 63.10
# 2019-11-06, Close, 63.03
# 2019-11-07, Close, 62.61
# 2019-11-08, Close, 63.10
# 2019-11-11, Close, 61.43
# 2019-11-12, Close, 61.98
# 2019-11-13, Close, 63.17
# 2019-11-14, Close, 65.20
# 2019-11-15, Close, 64.07
# 2019-11-18, Close, 64.21
# 2019-11-19, Close, 66.10
# 2019-11-20, Close, 65.66
# 2019-11-21, Close, 64.00
# 2019-11-22, Close, 61.50
# 2019-11-25, Close, 60.91
# 2019-11-26, Close, 61.44
# 2019-11-27, Close, 61.96
# 2019-11-28, Close, 61.98
# 2019-11-29, Close, 59.37
# 2019-12-02, Close, 57.87
# 2019-12-02, SELL CREATE, 57.87
# 2019-12-03, SELL EXECUTED, Price: 57.70, Cost: 44925.80, Comm 57.70
# 2019-12-03, OPERATION PROFIT, GROSS 12772.80, NET 12670.18
# 2019-12-03, Close, 58.44
# 2019-12-04, Close, 59.20
# 2019-12-05, Close, 59.38
# 2019-12-05, BUY CREATE, 59.38
# 2019-12-06, BUY EXECUTED, Price: 59.73, Cost: 59730.60, Comm 59.73
# 2019-12-06, Close, 60.20
# 2019-12-09, Close, 57.80
# 2019-12-09, SELL CREATE, 57.80
# 2019-12-10, SELL EXECUTED, Price: 57.37, Cost: 59730.60, Comm 57.37
# 2019-12-10, OPERATION PROFIT, GROSS -2363.80, NET -2480.90
# 2019-12-10, Close, 58.40
# 2019-12-11, Close, 58.75
# 2019-12-12, Close, 58.82
# 2019-12-13, Close, 60.03
# 2019-12-13, BUY CREATE, 60.03
# 2019-12-16, BUY EXECUTED, Price: 59.94, Cost: 59938.00, Comm 59.94
# 2019-12-16, Close, 58.92
# 2019-12-16, SELL CREATE, 58.92
# 2019-12-17, SELL EXECUTED, Price: 58.90, Cost: 59938.00, Comm 58.90
# 2019-12-17, OPERATION PROFIT, GROSS -1036.80, NET -1155.64
# 2019-12-17, Close, 59.47
# 2019-12-18, Close, 58.58
# 2019-12-19, Close, 58.65
# 2019-12-20, Close, 58.68
# 2019-12-23, Close, 58.91
# 2019-12-24, Close, 58.40
# 2019-12-25, Close, 57.63
# 2019-12-26, Close, 58.32
# 2019-12-27, Close, 58.32
# 2019-12-30, Close, 59.09
# 2019-12-31, Close, 60.49
# 2019-12-31, BUY CREATE, 60.49
# 2020-01-02, BUY EXECUTED, Price: 60.82, Cost: 60822.70, Comm 60.82
# 2020-01-02, Close, 60.60
# 2020-01-03, Close, 59.41
# 2020-01-03, SELL CREATE, 59.41
# 2020-01-06, SELL EXECUTED, Price: 59.13, Cost: 60822.70, Comm 59.13
# 2020-01-06, OPERATION PROFIT, GROSS -1693.40, NET -1813.35
# 2020-01-06, Close, 58.12
# 2020-01-07, Close, 58.66
# 2020-01-08, Close, 58.53
# 2020-01-09, Close, 60.05
# 2020-01-10, Close, 60.48
# 2020-01-13, Close, 60.71
# 2020-01-13, BUY CREATE, 60.71
# 2020-01-14, BUY EXECUTED, Price: 60.68, Cost: 60684.40, Comm 60.68
# 2020-01-14, Close, 59.79
# 2020-01-14, SELL CREATE, 59.79
# 2020-01-15, SELL EXECUTED, Price: 59.89, Cost: 60684.40, Comm 59.89
# 2020-01-15, OPERATION PROFIT, GROSS -794.80, NET -915.37
# 2020-01-15, Close, 60.08
# 2020-01-16, Close, 59.74
# 2020-01-17, Close, 62.66
# 2020-01-17, BUY CREATE, 62.66
# 2020-01-20, BUY EXECUTED, Price: 64.13, Cost: 64126.40, Comm 64.13
# 2020-01-20, Close, 62.27
# 2020-01-21, Close, 62.46
# 2020-01-22, Close, 62.43
# 2020-01-23, Close, 60.82
# 2020-02-03, Close, 59.07
# 2020-02-03, SELL CREATE, 59.07
# 2020-02-04, SELL EXECUTED, Price: 59.05, Cost: 64126.40, Comm 59.05
# 2020-02-04, OPERATION PROFIT, GROSS -5073.10, NET -5196.28
# 2020-02-04, Close, 59.96
# 2020-02-05, Close, 61.45
# 2020-02-05, BUY CREATE, 61.45
# 2020-02-06, BUY EXECUTED, Price: 61.82, Cost: 61824.90, Comm 61.82
# 2020-02-06, Close, 62.27
# 2020-02-07, Close, 61.96
# 2020-02-10, Close, 61.17
# 2020-02-11, Close, 62.31
# 2020-02-12, Close, 64.25
# 2020-02-13, Close, 63.21
# 2020-02-14, Close, 63.28
# 2020-02-17, Close, 63.85
# 2020-02-18, Close, 62.62
# 2020-02-19, Close, 61.98
# 2020-02-20, Close, 62.76
# 2020-02-21, Close, 62.34
# 2020-02-24, Close, 61.09
# 2020-02-25, Close, 61.04
# 2020-02-26, Close, 59.91
# 2020-02-26, SELL CREATE, 59.91
# 2020-02-27, SELL EXECUTED, Price: 60.13, Cost: 61824.90, Comm 60.13
# 2020-02-27, OPERATION PROFIT, GROSS -1693.40, NET -1815.36
# 2020-02-27, Close, 60.28
# 2020-02-28, Close, 58.12
# 2020-03-02, Close, 58.89
# 2020-03-03, Close, 61.06
# 2020-03-03, BUY CREATE, 61.06
# 2020-03-04, BUY EXECUTED, Price: 60.82, Cost: 60822.70, Comm 60.82
# 2020-03-04, Close, 60.68
# 2020-03-05, Close, 63.38
# 2020-03-06, Close, 63.76
# 2020-03-09, Close, 61.44
# 2020-03-10, Close, 62.62
# 2020-03-11, Close, 61.53
# 2020-03-12, Close, 59.70
# 2020-03-12, SELL CREATE, 59.70
# 2020-03-13, SELL EXECUTED, Price: 56.81, Cost: 60822.70, Comm 56.81
# 2020-03-13, OPERATION PROFIT, GROSS -4008.80, NET -4126.44
# 2020-03-13, Close, 58.54
# 2020-03-16, Close, 56.71
# 2020-03-17, Close, 56.05
# 2020-03-18, Close, 55.71
# 2020-03-19, Close, 54.60
# 2020-03-20, Close, 55.40
# 2020-03-23, Close, 56.88
# 2020-03-24, Close, 59.21
# 2020-03-25, Close, 61.49
# 2020-03-25, BUY CREATE, 61.49
# 2020-03-26, BUY EXECUTED, Price: 61.44, Cost: 61444.70, Comm 61.44
# 2020-03-26, Close, 62.40
# 2020-03-27, Close, 62.82
# 2020-03-30, Close, 62.69
# 2020-03-31, Close, 63.61
# 2020-04-01, Close, 62.20
# 2020-04-02, Close, 63.48
# 2020-04-03, Close, 64.78
# 2020-04-07, Close, 66.01
# 2020-04-08, Close, 65.51
# 2020-04-09, Close, 66.90
# 2020-04-10, Close, 66.50
# 2020-04-13, Close, 66.82
# 2020-04-14, Close, 68.07
# 2020-04-15, Close, 67.34
# 2020-04-16, Close, 67.33
# 2020-04-17, Close, 66.77
# 2020-04-20, Close, 66.84
# 2020-04-21, Close, 65.87
# 2020-04-22, Close, 67.39
# 2020-04-23, Close, 66.39
# 2020-04-24, Close, 65.85
# 2020-04-27, Close, 66.59
# 2020-04-28, Close, 66.39
# 2020-04-29, Close, 64.55
# 2020-04-30, Close, 64.28
# 2020-05-06, Close, 66.64
# 2020-05-07, Close, 66.77
# 2020-05-08, Close, 67.08
# 2020-05-11, Close, 64.75
# 2020-05-12, Close, 65.96
# 2020-05-13, Close, 66.14
# 2020-05-14, Close, 67.18
# 2020-05-15, Close, 65.54
# 2020-05-18, Close, 67.18
# 2020-05-19, Close, 67.69
# 2020-05-20, Close, 67.67
# 2020-05-21, Close, 68.94
# 2020-05-22, Close, 66.27
# 2020-05-25, Close, 67.30
# 2020-05-26, Close, 67.76
# 2020-05-27, Close, 66.40
# 2020-05-28, Close, 65.26
# 2020-05-29, Close, 65.43
# 2020-06-01, Close, 66.69
# 2020-06-02, Close, 66.84
# 2020-06-03, Close, 66.65
# 2020-06-04, Close, 67.51
# 2020-06-05, Close, 68.42
# 2020-06-08, Close, 66.76
# 2020-06-09, Close, 68.98
# 2020-06-10, Close, 70.28
# 2020-06-11, Close, 70.22
# 2020-06-12, Close, 71.36
# 2020-06-15, Close, 70.03
# 2020-06-16, Close, 72.45
# 2020-06-17, Close, 74.53
# 2020-06-18, Close, 74.24
# 2020-06-19, Close, 77.30
# 2020-06-22, Close, 77.51
# 2020-06-23, Close, 78.56
# 2020-06-24, Close, 77.28
# 2020-06-29, Close, 76.68
# 2020-06-30, Close, 76.74
# 2020-07-01, Close, 75.70
# 2020-07-02, Close, 75.82
# 2020-07-03, Close, 76.39
# 2020-07-06, Close, 77.43
# 2020-07-07, Close, 80.88
# 2020-07-08, Close, 80.69
# 2020-07-09, Close, 81.90
# 2020-07-10, Close, 82.60
# 2020-07-13, Close, 82.99
# 2020-07-14, Close, 81.83
# 2020-07-15, Close, 85.62
# 2020-07-16, Close, 80.10
# 2020-07-17, Close, 80.09
# 2020-07-20, Close, 80.22
# 2020-07-21, Close, 82.56
# 2020-07-22, Close, 82.61
# 2020-07-23, Close, 82.61
# 2020-07-24, Close, 78.81
# 2020-07-27, Close, 79.30
# 2020-07-28, Close, 78.65
# 2020-07-29, Close, 79.69
# 2020-07-30, Close, 78.96
# 2020-07-31, Close, 78.46
# 2020-08-03, Close, 77.48
# 2020-08-04, Close, 78.13
# 2020-08-05, Close, 77.14
# 2020-08-06, Close, 75.65
# 2020-08-07, Close, 75.82
# 2020-08-10, Close, 75.48
# 2020-08-11, Close, 76.30
# 2020-08-12, Close, 74.83
# 2020-08-12, SELL CREATE, 74.83
# 2020-08-13, SELL EXECUTED, Price: 75.60, Cost: 61444.70, Comm 75.60
# 2020-08-13, OPERATION PROFIT, GROSS 14152.00, NET 14014.96
# 2020-08-13, Close, 73.89
# 2020-08-14, Close, 74.41
# 2020-08-17, Close, 75.57
# 2020-08-17, BUY CREATE, 75.57
# 2020-08-18, BUY EXECUTED, Price: 75.82, Cost: 75821.20, Comm 75.82
# 2020-08-18, Close, 77.65
# 2020-08-19, Close, 77.09
# 2020-08-20, Close, 76.24
# 2020-08-21, Close, 76.32
# 2020-08-24, Close, 76.84
# 2020-08-25, Close, 78.14
# 2020-08-26, Close, 78.63
# 2020-08-27, Close, 78.24
# 2020-08-28, Close, 79.30
# 2020-08-31, Close, 78.87
# 2020-09-01, Close, 78.14
# 2020-09-02, Close, 78.73
# 2020-09-03, Close, 78.98
# 2020-09-04, Close, 77.74
# 2020-09-04, SELL CREATE, 77.74
# 2020-09-07, SELL EXECUTED, Price: 77.32, Cost: 75821.20, Comm 77.32
# 2020-09-07, OPERATION PROFIT, GROSS 1496.50, NET 1343.36
# 2020-09-07, Close, 76.15
# 2020-09-08, Close, 76.76
# 2020-09-09, Close, 75.07
# 2020-09-10, Close, 75.44
# 2020-09-11, Close, 76.33
# 2020-09-14, Close, 75.95
# 2020-09-15, Close, 75.74
# 2020-09-16, Close, 74.61
# 2020-09-17, Close, 71.74
# 2020-09-18, Close, 73.98
# 2020-09-21, Close, 73.58
# 2020-09-22, Close, 74.24
# 2020-09-23, Close, 74.69
# 2020-09-24, Close, 73.04
# 2020-09-25, Close, 73.53
# 2020-09-28, Close, 73.64
# 2020-09-29, Close, 74.73
# 2020-09-30, Close, 74.67
# 2020-10-09, Close, 76.44
# 2020-10-12, Close, 78.32
# 2020-10-12, BUY CREATE, 78.32
# 2020-10-13, BUY EXECUTED, Price: 78.32, Cost: 78315.30, Comm 78.32
# 2020-10-13, Close, 77.90
# 2020-10-14, Close, 77.32
# 2020-10-15, Close, 77.45
# 2020-10-16, Close, 77.40
# 2020-10-19, Close, 76.09
# 2020-10-19, SELL CREATE, 76.09
# 2020-10-20, SELL EXECUTED, Price: 75.98, Cost: 78315.30, Comm 75.98
# 2020-10-20, OPERATION PROFIT, GROSS -2336.20, NET -2490.49
# 2020-10-20, Close, 75.66
# 2020-10-21, Close, 74.47
# 2020-10-22, Close, 74.46
# 2020-10-23, Close, 73.29
# 2020-10-26, Close, 74.14
# 2020-10-27, Close, 74.18
# 2020-10-28, Close, 75.95
# 2020-10-29, Close, 75.69
# 2020-10-30, Close, 73.86
# 2020-11-02, Close, 74.18
# 2020-11-03, Close, 74.95
# 2020-11-04, Close, 74.96
# 2020-11-05, Close, 75.82
# 2020-11-06, Close, 73.90
# 2020-11-09, Close, 74.30
# 2020-11-10, Close, 73.12
# 2020-11-11, Close, 71.64
# 2020-11-12, Close, 71.96
# 2020-11-13, Close, 71.08
# 2020-11-16, Close, 71.19
# 2020-11-17, Close, 71.11
# 2020-11-18, Close, 72.01
# 2020-11-19, Close, 72.58
# 2020-11-20, Close, 72.25
# 2020-11-23, Close, 71.60
# 2020-11-24, Close, 72.47
# 2020-11-25, Close, 71.61
# 2020-11-26, Close, 71.50
# 2020-11-27, Close, 72.29
# 2020-11-30, Close, 71.49
# 2020-12-01, Close, 72.84
# 2020-12-02, Close, 72.77
# 2020-12-03, Close, 74.82
# 2020-12-03, BUY CREATE, 74.82
# 2020-12-04, BUY EXECUTED, Price: 74.73, Cost: 74732.10, Comm 74.73
# 2020-12-04, Close, 75.92
# 2020-12-07, Close, 74.72
# 2020-12-08, Close, 74.88
# 2020-12-09, Close, 73.36
# 2020-12-09, SELL CREATE, 73.36
# 2020-12-10, SELL EXECUTED, Price: 73.16, Cost: 74732.10, Comm 73.16
# 2020-12-10, OPERATION PROFIT, GROSS -1571.30, NET -1719.19
# 2020-12-10, Close, 73.99
# 2020-12-11, Close, 74.41
# 2020-12-11, BUY CREATE, 74.41
# 2020-12-14, BUY EXECUTED, Price: 74.01, Cost: 74008.80, Comm 74.01
# 2020-12-14, Close, 74.92
# 2020-12-15, Close, 80.66
# 2020-12-16, Close, 80.65
# 2020-12-17, Close, 87.44
# 2020-12-18, Close, 87.84
# 2020-12-21, Close, 89.67
# 2020-12-22, Close, 88.29
# 2020-12-23, Close, 88.13
# 2020-12-24, Close, 90.45
# 2020-12-25, Close, 95.62
# 2020-12-28, Close, 92.28
# 2020-12-29, Close, 90.02
# 2020-12-30, Close, 93.70
# 2020-12-31, Close, 92.66
# 2021-01-04, Close, 92.45
# 2021-01-05, Close, 94.14
# 2021-01-06, Close, 94.54
# 2021-01-07, Close, 95.61
# 2021-01-08, Close, 94.13
# 2021-01-11, Close, 92.53
# 2021-01-12, Close, 94.86
# 2021-01-13, Close, 93.59
# 2021-01-14, Close, 91.60
# 2021-01-15, Close, 91.31
# 2021-01-18, Close, 89.65
# 2021-01-19, Close, 87.25
# 2021-01-20, Close, 88.10
# 2021-01-21, Close, 89.91
# 2021-01-22, Close, 93.61
# 2021-01-25, Close, 92.66
# 2021-01-26, Close, 88.96
# 2021-01-27, Close, 88.64
# 2021-01-28, Close, 87.01
# 2021-01-29, Close, 86.26
# 2021-02-01, Close, 85.26
# 2021-02-02, Close, 88.13
# 2021-02-03, Close, 87.29
# 2021-02-04, Close, 85.47
# 2021-02-05, Close, 89.21
# 2021-02-08, Close, 88.36
# 2021-02-09, Close, 91.23
# 2021-02-10, Close, 90.79
# 2021-02-18, Close, 87.21
# 2021-02-19, Close, 87.43
# 2021-02-22, Close, 83.15
# 2021-02-22, SELL CREATE, 83.15
# 2021-02-23, SELL EXECUTED, Price: 82.59, Cost: 74008.80, Comm 82.59
# 2021-02-23, OPERATION PROFIT, GROSS 8579.80, NET 8423.20
# 2021-02-23, Close, 83.72
# 2021-02-24, Close, 82.89
# 2021-02-25, Close, 84.01
# 2021-02-26, Close, 84.63
# 2021-03-01, Close, 83.39
# 2021-03-02, Close, 81.77
# 2021-03-03, Close, 84.26
# 2021-03-04, Close, 83.55
# 2021-03-05, Close, 83.39
# 2021-03-08, Close, 76.59
# 2021-03-09, Close, 76.30
# 2021-03-10, Close, 77.65
# 2021-03-11, Close, 77.72
# 2021-03-12, Close, 76.64
# 2021-03-15, Close, 74.48
# 2021-03-16, Close, 74.15
# 2021-03-17, Close, 73.68
# 2021-03-18, Close, 74.17
# 2021-03-19, Close, 73.20
# 2021-03-22, Close, 73.25
# 2021-03-23, Close, 72.87
# 2021-03-24, Close, 71.93
# 2021-03-25, Close, 72.52
# 2021-03-26, Close, 75.84
# 2021-03-29, Close, 75.26
# 2021-03-30, Close, 77.82
# 2021-03-31, Close, 76.56
# 2021-04-01, Close, 78.02
# 2021-04-02, Close, 77.05
# 2021-04-06, Close, 75.57
# 2021-04-07, Close, 75.39
# 2021-04-08, Close, 76.85
# 2021-04-09, Close, 75.82
# 2021-04-12, Close, 74.43
# 2021-04-13, Close, 73.98
# 2021-04-14, Close, 71.10
# 2021-04-15, Close, 68.32
# 2021-04-16, Close, 67.03
# 2021-04-19, Close, 68.25
# 2021-04-20, Close, 66.77
# 2021-04-21, Close, 69.15
# 2021-04-22, Close, 68.34
# 2021-04-23, Close, 69.00
# 2021-04-26, Close, 67.77
# 2021-04-27, Close, 69.05
# 2021-04-28, Close, 68.89
# 2021-04-29, Close, 68.46
# 2021-04-30, Close, 69.92
# 2021-05-06, Close, 68.27
# 2021-05-07, Close, 66.50
# 2021-05-10, Close, 66.78
# 2021-05-11, Close, 69.59
# 2021-05-12, Close, 69.15
# 2021-05-13, Close, 67.95
# 2021-05-14, Close, 69.69
# 2021-05-17, Close, 70.98
# 2021-05-18, Close, 71.27
# 2021-05-19, Close, 70.71
# 2021-05-20, Close, 69.59
# 2021-05-21, Close, 68.31
# 2021-05-24, Close, 69.30
# 2021-05-25, Close, 71.71
# 2021-05-26, Close, 71.74
# 2021-05-27, Close, 71.76
# 2021-05-28, Close, 71.37
# 2021-05-31, Close, 71.75
# 2021-06-01, Close, 72.72
# 2021-06-01, BUY CREATE, 72.72
# 2021-06-02, BUY EXECUTED, Price: 72.75, Cost: 72753.40, Comm 72.75
# 2021-06-02, Close, 70.13
# 2021-06-02, SELL CREATE, 70.13
# 2021-06-03, SELL EXECUTED, Price: 69.44, Cost: 72753.40, Comm 69.44
# 2021-06-03, OPERATION PROFIT, GROSS -3308.80, NET -3451.00
# 2021-06-03, Close, 68.65
# 2021-06-04, Close, 68.71
# 2021-06-07, Close, 68.54
# 2021-06-08, Close, 68.99
# 2021-06-09, Close, 69.96
# 2021-06-10, Close, 73.00
# 2021-06-10, BUY CREATE, 73.00
# 2021-06-11, BUY EXECUTED, Price: 73.10, Cost: 73100.00, Comm 73.10
# 2021-06-11, Close, 72.96
# 2021-06-15, Close, 71.88
# 2021-06-16, Close, 70.81
# 2021-06-16, SELL CREATE, 70.81
# 2021-06-17, SELL EXECUTED, Price: 70.84, Cost: 73100.00, Comm 70.84
# 2021-06-17, OPERATION PROFIT, GROSS -2260.00, NET -2403.94
# 2021-06-17, Close, 71.15
# 2021-06-18, Close, 71.44
# 2021-06-18, BUY CREATE, 71.44
# 2021-06-21, BUY EXECUTED, Price: 71.20, Cost: 71200.00, Comm 71.20
# 2021-06-21, Close, 69.51
# 2021-06-21, SELL CREATE, 69.51
# 2021-06-22, SELL EXECUTED, Price: 69.51, Cost: 71200.00, Comm 69.51
# 2021-06-22, OPERATION PROFIT, GROSS -1690.00, NET -1830.71
# 2021-06-22, Close, 70.48
# 2021-06-23, Close, 71.15
# 2021-06-23, BUY CREATE, 71.15
# 2021-06-24, BUY EXECUTED, Price: 69.99, Cost: 69990.00, Comm 69.99
# 2021-06-24, Close, 68.00
# 2021-06-24, SELL CREATE, 68.00
# 2021-06-25, SELL EXECUTED, Price: 67.67, Cost: 69990.00, Comm 67.67
# 2021-06-25, OPERATION PROFIT, GROSS -2320.00, NET -2457.66
# 2021-06-25, Close, 68.06
# 2021-06-28, Close, 68.60
# 2021-06-29, Close, 68.20
# 2021-06-30, Close, 67.97
# 2021-07-01, Close, 69.69
# 2021-07-02, Close, 66.91
# 2021-07-05, Close, 62.95
# 2021-07-06, Close, 62.06
# 2021-07-07, Close, 62.45
# 2021-07-08, Close, 61.37
# 2021-07-09, Close, 62.10
# 2021-07-12, Close, 63.12
# 2021-07-13, Close, 61.94
# 2021-07-14, Close, 60.11
# 2021-07-15, Close, 60.27
# 2021-07-16, Close, 60.10
# 2021-07-19, Close, 60.96
# 2021-07-20, Close, 63.18
# 2021-07-21, Close, 62.98
# 2021-07-22, Close, 61.28
# 2021-07-23, Close, 61.49
# 2021-07-26, Close, 59.22
# 2021-07-27, Close, 54.50
# 2021-07-28, Close, 55.91
# 2021-07-29, Close, 55.11
# 2021-07-30, Close, 54.38
# 2021-08-02, Close, 55.25
# 2021-08-03, Close, 57.40
# 2021-08-04, Close, 56.33
# 2021-08-05, Close, 55.80
# 2021-08-06, Close, 54.80
# 2021-08-09, Close, 56.92
# 2021-08-10, Close, 57.74
# 2021-08-11, Close, 56.89
# 2021-08-12, Close, 55.80
# 2021-08-13, Close, 56.53
# 2021-08-16, Close, 56.47
# 2021-08-17, Close, 54.75
# 2021-08-18, Close, 54.99
# 2021-08-19, Close, 53.84
# 2021-08-20, Close, 48.46
# 2021-08-23, Close, 47.18
# 2021-08-24, Close, 47.20
# 2021-08-25, Close, 47.41
# 2021-08-26, Close, 45.31
# 2021-08-27, Close, 46.05
# 2021-08-30, Close, 45.60
# 2021-08-31, Close, 45.20
# 2021-09-01, Close, 46.59
# 2021-09-02, Close, 45.86
# 2021-09-03, Close, 46.10
# 2021-09-06, Close, 48.10
# Final Portfolio Value: 124194.55
# <div id='1e62fa55-f3eb-4638-bcf4-bafba63a3979'></div>
# [[<Figure size 600x400 with 7 Axes>]]

# %% [markdown]
# ## 策略优化：以调整SMA参数为例

# %%
# Create a Stratey
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 15),
        ('printlog', False),
    )

    def log(self, txt, dt=None, doprint=False):
        # 参数：printlog、doprint，初始均设置为False，参数printlog控制细节结果输出
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        self.dataclose = self.datas[0].close
        self.order = None
        self.buyprice = None
        self.buycomm = None

        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' % (trade.pnl, trade.pnlcomm))

    def next(self):
        self.log('Close, %.2f' % self.dataclose[0])

        if self.order:
            return

        if not self.position:

            if self.dataclose[0] > self.sma[0]:
                self.log('BUY CREATE, %.2f' % self.dataclose[0])
                self.order = self.buy()

        else:

            if self.dataclose[0] < self.sma[0]:
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                self.order = self.sell()

    def stop(self):
        # 参数doprint=True，控制log函数打印以下结果
        self.log('(MA Period %2d) Ending Value %.2f' % (self.params.maperiod, self.broker.getvalue()), doprint=True)


# Create a cerebro entity
cerebro = bt.Cerebro()

# Add a strategy
strats = cerebro.optstrategy(TestStrategy,maperiod=range(10, 120, 5))

# 添加数据源
data = bt.feeds.PandasData(dataname=df)

# 输入数据源
cerebro.adddata(data)

# Set our desired cash start
cerebro.broker.setcash(1000.0)

# Add a FixedSize sizer according to the stake
cerebro.addsizer(bt.sizers.FixedSize, stake=10)

# Set the commission
cerebro.broker.setcommission(commission=0.0)

# Run over everything
cerebro.run(maxcpus=1)
# Out:
# 2021-09-06, (MA Period 10) Ending Value 875.79
# 2021-09-06, (MA Period 15) Ending Value 1089.22
# 2021-09-06, (MA Period 20) Ending Value 1135.87
# 2021-09-06, (MA Period 25) Ending Value 1100.01
# 2021-09-06, (MA Period 30) Ending Value 1225.00
# 2021-09-06, (MA Period 35) Ending Value 1346.81
# 2021-09-06, (MA Period 40) Ending Value 1263.91
# 2021-09-06, (MA Period 45) Ending Value 1241.21
# 2021-09-06, (MA Period 50) Ending Value 1275.95
# 2021-09-06, (MA Period 55) Ending Value 1276.11
# 2021-09-06, (MA Period 60) Ending Value 1274.00
# 2021-09-06, (MA Period 65) Ending Value 1317.69
# 2021-09-06, (MA Period 70) Ending Value 1341.51
# 2021-09-06, (MA Period 75) Ending Value 1372.77
# 2021-09-06, (MA Period 80) Ending Value 1360.12
# 2021-09-06, (MA Period 85) Ending Value 1430.61
# 2021-09-06, (MA Period 90) Ending Value 1369.22
# 2021-09-06, (MA Period 95) Ending Value 1385.95
# 2021-09-06, (MA Period 100) Ending Value 1424.73
# 2021-09-06, (MA Period 105) Ending Value 1438.00
# 2021-09-06, (MA Period 110) Ending Value 1389.09
# 2021-09-06, (MA Period 115) Ending Value 1407.38
# [[<backtrader.cerebro.OptReturn at 0x1f54047b6c8>],
#  [<backtrader.cerebro.OptReturn at 0x1f53f4a04c8>],
#  [<backtrader.cerebro.OptReturn at 0x1f53f32f648>],
#  [<backtrader.cerebro.OptReturn at 0x1f5404e6a08>],
#  [<backtrader.cerebro.OptReturn at 0x1f53f0881c8>],
#  [<backtrader.cerebro.OptReturn at 0x1f5404f4208>],
#  [<backtrader.cerebro.OptReturn at 0x1f5402b8e88>],
#  [<backtrader.cerebro.OptReturn at 0x1f54021e488>],
#  [<backtrader.cerebro.OptReturn at 0x1f540229808>],
#  [<backtrader.cerebro.OptReturn at 0x1f5406d4d48>],
#  [<backtrader.cerebro.OptReturn at 0x1f540264a88>],
#  [<backtrader.cerebro.OptReturn at 0x1f53f487388>],
#  [<backtrader.cerebro.OptReturn at 0x1f53f577188>],
#  [<backtrader.cerebro.OptReturn at 0x1f540264148>],
#  [<backtrader.cerebro.OptReturn at 0x1f53f0ab088>],
#  [<backtrader.cerebro.OptReturn at 0x1f53ff8ce48>],
#  [<backtrader.cerebro.OptReturn at 0x1f540061648>],
#  [<backtrader.cerebro.OptReturn at 0x1f53eeb2e48>],
#  [<backtrader.cerebro.OptReturn at 0x1f53ef7c588>],
#  [<backtrader.cerebro.OptReturn at 0x1f5405f09c8>],
#  [<backtrader.cerebro.OptReturn at 0x1f540229c88>],
#  [<backtrader.cerebro.OptReturn at 0x1f540514e48>]]
